# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import random
import os

# %%
def invlogit(a):
    return np.exp(a)/(1+np.exp(a))

a = np.arange(-5,5,0.01)
plt.plot(a,invlogit(a))

# %%
invlogit(1)
# Out:
# 0.7310585786300049
