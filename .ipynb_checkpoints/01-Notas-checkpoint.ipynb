# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import random

# %%
df = pd.read_csv('data/enem19-1perc.csv')
df
# Out:
#        NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0      190001005339    2019                  1501006                  Aveiro
# 1      190001005389    2019                  1502400               Castanhal
# 2      190001005934    2019                  1507953               Tailândia
# 3      190001006149    2019                  1501402                   Belém
# 4      190001006315    2019                  1505502             Paragominas
# ...             ...     ...                      ...                     ...
# 31653  190006119170    2019                  5201306                 Anicuns
# 31654  190006119205    2019                  5211404                  Itauçu
# 31655  190006119705    2019                  2211001                Teresina
# 31656  190006119799    2019                  2311801                  Russas
# 31657  190006120055    2019                  2901155         América Dourada
#
#        CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                    15               PA        20       F                1
# 1                    15               PA        24       F                1
# 2                    15               PA        24       M                1
# 3                    15               PA        35       M                1
# 4                    15               PA        17       F                1
# ...                 ...              ...       ...     ...              ...
# 31653                52               GO        19       M                1
# 31654                52               GO        18       M                1
# 31655                22               PI        18       M                1
# 31656                23               CE        17       M                1
# 31657                29               BA        18       M                1
#
#        TP_COR_RACA  ...  Q016  Q017 Q018  Q019 Q020  Q021  Q022  Q023  Q024  \
# 0                1  ...     A     A    A     B    B     A     E     A     A
# 1                3  ...     A     A    A     B    A     A     D     B     B
# 2                3  ...     A     A    A     B    B     A     D     A     A
# 3                1  ...     B     A    A     C    B     A     D     B     A
# 4                3  ...     B     A    A     B    A     A     B     A     B
# ...            ...  ...   ...   ...  ...   ...  ...   ...   ...   ...   ...
# 31653            1  ...     A     A    A     B    A     A     D     A     B
# 31654            1  ...     B     A    A     B    B     B     D     B     B
# 31655            3  ...     A     A    A     B    A     A     E     A     A
# 31656            3  ...     A     A    A     B    A     A     B     A     A
# 31657            2  ...     B     A    A     C    A     B     E     A     D
#
#        Q025
# 0         B
# 1         B
# 2         B
# 3         B
# 4         B
# ...     ...
# 31653     B
# 31654     B
# 31655     A
# 31656     A
# 31657     B
#
# [31658 rows x 136 columns]

# %% [markdown]
# # Algumas análises preliminares

# %%
mt = df['NU_NOTA_MT']
ax = mt.hist(bins=100)

# %%
df['TP_SEXO'].value_counts()
# Out:
# F    18638
# M    13020
# Name: TP_SEXO, dtype: int64

# %%
df['TP_COR_RACA'].value_counts()
# Out:
# 3    14796
# 1    11066
# 2     4213
# 4      791
# 0      596
# 5      196
# Name: TP_COR_RACA, dtype: int64

# %%
df["NU_NOTA_MT"].describe()
# Out:
# count    31658.000000
# mean       520.918185
# std        110.046439
# min          0.000000
# 25%        432.300000
# 50%        497.700000
# 75%        594.600000
# max        984.200000
# Name: NU_NOTA_MT, dtype: float64

# %%
df.query("TP_SEXO == 'F'")["NU_NOTA_MT"].describe()
# Out:
# count    18638.000000
# mean       503.156868
# std        100.835328
# min          0.000000
# 25%        424.500000
# 50%        479.400000
# 75%        564.600000
# max        975.200000
# Name: NU_NOTA_MT, dtype: float64
