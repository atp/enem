# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Leitura dos dados

# %%
#leitura com pandas
notas_selecao = pd.read_csv('data/enem19-sem_Zzero.csv')
notas_selecao
# Out:
#        NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0      190001004967    2019                  1506807                Santarém
# 1      190001005059    2019                  1506807                Santarém
# 2      190001005138    2019                  1508100                 Tucuruí
# 3      190001005147    2019                  1505205          Oeiras do Pará
# 4      190001005219    2019                  1502954     Eldorado do Carajás
# ...             ...     ...                      ...                     ...
# 31462  190006119878    2019                  2610608                Paudalho
# 31463  190006119928    2019                  2700300               Arapiraca
# 31464  190006120038    2019                  2912103                Ibicaraí
# 31465  190006120062    2019                  2927408                Salvador
# 31466  190006120091    2019                  3155603      Rio Pardo de Minas
#
# ...

# %% [markdown]
# ## Gráficos interessantes dos dados do ENEM

# %% [markdown]
# ### Grafico de barra

# %%
disp = sns.barplot(data=notas_selecao, x="TP_SEXO", y="NU_NOTA_MT")
disp
#Interessante adicionar alguns detalhes adicionais no gráfico
# Out:
# <AxesSubplot:xlabel='TP_SEXO', ylabel='NU_NOTA_MT'>

# %% [markdown]
# ### Boxplot da nota de matematica por sexo

# %%
sns.boxplot(data=notas_selecao,  x="TP_SEXO", y="NU_NOTA_MT")
# Out:
# <AxesSubplot:xlabel='TP_SEXO', ylabel='NU_NOTA_MT'>

# %% [markdown]
# ### Boxplot da nota de linguas por sexo

# %%
sns.boxplot(data=notas_selecao,  x="TP_SEXO", y="NU_NOTA_LC")
# Out:
# <AxesSubplot:xlabel='TP_SEXO', ylabel='NU_NOTA_LC'>

# %% [markdown]
# #### Posivel veirifcar um equilibrio bem maior nesta disciplina e que ha mais  outliers para as mulheres

# %% [markdown]
# ### Grafico de regressao linear para relacao de nota e idade

# %%
sns.regplot(data=notas_selecao, x="NU_NOTA_MT",y="NU_IDADE")
#Este grafico nao faz muito sentido, porpem ainda estou testando.
# Out:
# <AxesSubplot:xlabel='NU_NOTA_MT', ylabel='NU_IDADE'>
