# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
import scipy.stats as stats
import pickle

# %%
import rpy2
import numpy as np

import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri

import rpy2.ipython.html
rpy2.ipython.html.init_printing()

from rpy2.robjects.packages import importr, data


utils = importr('utils')
base = importr('base')
# %load_ext rpy2.ipython

# %%
def to_rdf(df):
    with (robjects.default_converter + pandas2ri.converter).context():
        rdf = robjects.conversion.get_conversion().py2rpy(df)
    return rdf

def to_df(rdf):
    with (robjects.default_converter + pandas2ri.converter).context():
        df = robjects.conversion.get_conversion().rpy2py(rdf)

    return df
summary = rpy2.robjects.r['summary']
coef = rpy2.robjects.r['coef']
rprint = rpy2.robjects.r['print']
plot = rpy2.robjects.r['plot']

# %%
# %%R
# R.version.string
# Out:
# [1] "R version 4.3.1 (2023-06-16)"
# In addition: Warning messages:
# 1: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   library ‘/dados1/usr/lib/R/site-library’ contains no packages
# 2: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   library ‘/dados1/usr/lib/R/site-library’ contains no packages
# 3: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   library ‘/dados1/usr/lib/R/site-library’ contains no packages

# %% [markdown]
# ## Instalar pacotes do R localmente (só para seu usuário)
# Talvez é necessário usar
# ```
# utils.install_packages('mirt')
# utils.install_packages('mirtCAT')
#
# ```
# e o equivalente de outros pacotes. Deu erro instalar devtools desta forma, mas consegui instalar no rstudio.atp.usp.br. agora a linha abaixo funciona:

# %%
#devtools.install_github('alexandrejaloto/microEnem')

# %%
utils.install_packages('mirt')
utils.install_packages('mirtCAT')
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: Warning in (function (pkgs, lib, repos = getOption("repos"), contriburl = contrib.url(repos,  :
# R[write to console]:
#
# R[write to console]:  'lib = "/usr/local/lib/R/site-library"' is not writable
# Would you like to use a personal library instead? (yes/No/cancel)  yes
# Would you like to create a personal library
# ‘/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3’
# to install packages into? (yes/No/cancel)  yes
# R[write to console]: also installing the dependencies ‘permute’, ‘GPArotation’, ‘gridExtra’, ‘vegan’, ‘Deriv’, ‘pbapply’, ‘dcurver’, ‘RcppArmadillo’
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/permute_0.9-7.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 114805 bytes (112 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 112 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/GPArotation_2023.11-1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 308299 bytes (301 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 301 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/gridExtra_2.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1062844 bytes (1.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.0 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/vegan_2.6-4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1496110 bytes (1.4 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.4 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/Deriv_4.1.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 37214 bytes (36 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 36 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/pbapply_1.7-2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 23980 bytes (23 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 23 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/dcurver_0.9.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 11409 bytes (11 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 11 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/RcppArmadillo_0.12.6.6.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1403237 bytes (1.3 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.3 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/mirt_1.41.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 535915 bytes (523 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 523 KB
#
#
# * installing *source* package ‘permute’ ...
# ** package ‘permute’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (permute)
# * installing *source* package ‘GPArotation’ ...
# ** package ‘GPArotation’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (GPArotation)
# * installing *source* package ‘gridExtra’ ...
# ** package ‘gridExtra’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (gridExtra)
# * installing *source* package ‘Deriv’ ...
# ** package ‘Deriv’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (Deriv)
# * installing *source* package ‘pbapply’ ...
# ** package ‘pbapply’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (pbapply)
# * installing *source* package ‘RcppArmadillo’ ...
# ** package ‘RcppArmadillo’ successfully unpacked and MD5 sums checked
# ** using staged installation
# checking whether the C++ compiler works... yes
# checking for C++ compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether the compiler supports GNU C++... yes
# checking whether g++ -std=gnu++14 accepts -g... yes
# checking for g++ -std=gnu++14 option to enable C++11 features... none needed
# checking how to run the C++ preprocessor... g++ -std=gnu++14 -E
# checking whether the compiler supports GNU C++... (cached) yes
# checking whether g++ -std=gnu++14 accepts -g... (cached) yes
# checking for g++ -std=gnu++14 option to enable C++11 features... (cached) none needed
# checking whether we have a suitable tempdir... /tmp
# checking whether R CMD SHLIB can already compile programs using OpenMP... yes
# checking LAPACK_LIBS... system LAPACK found
# configure: creating ./config.status
# config.status: creating inst/include/RcppArmadillo/config/RcppArmadilloConfigGenerated.h
# config.status: creating src/Makevars
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -I../inst/include -I'/usr/local/lib/R/site-library/Rcpp/include'    -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c RcppArmadillo.cpp -o RcppArmadillo.o
# ** libs
# using C++ compiler: ‘g++ (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609’
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -I../inst/include -I'/usr/local/lib/R/site-library/Rcpp/include'    -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c RcppExports.cpp -o RcppExports.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -I../inst/include -I'/usr/local/lib/R/site-library/Rcpp/include'    -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c fastLm.cpp -o fastLm.o
# g++ -std=gnu++14 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o RcppArmadillo.so RcppArmadillo.o RcppExports.o fastLm.o -fopenmp -llapack -lblas -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR
# installing to /dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/00LOCK-RcppArmadillo/00new/RcppArmadillo/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (RcppArmadillo)
# * installing *source* package ‘vegan’ ...
# ** package ‘vegan’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘gcc (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609’
# using Fortran compiler: ‘GNU Fortran (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609’
# gcc -I"/usr/share/R/include" -DNDEBUG       -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c data2hill.c -o data2hill.o
# gfortran  -fpic  -g -O2 -fstack-protector-strong  -c decorana.f -o decorana.o
# gcc -I"/usr/share/R/include" -DNDEBUG       -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c getF.c -o getF.o
# gcc -I"/usr/share/R/include" -DNDEBUG       -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c goffactor.c -o goffactor.o
# gcc -I"/usr/share/R/include" -DNDEBUG       -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c init.c -o init.o
# gfortran  -fpic  -g -O2 -fstack-protector-strong  -c monoMDS.f -o monoMDS.o
# gcc -I"/usr/share/R/include" -DNDEBUG       -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c nestedness.c -o nestedness.o
# gfortran  -fpic  -g -O2 -fstack-protector-strong  -c ordering.f -o ordering.o
# gcc -I"/usr/share/R/include" -DNDEBUG       -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c pnpoly.c -o pnpoly.o
# gcc -I"/usr/share/R/include" -DNDEBUG       -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c stepacross.c -o stepacross.o
# gcc -I"/usr/share/R/include" -DNDEBUG       -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c vegdist.c -o vegdist.o
# gcc -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o vegan.so data2hill.o decorana.o getF.o goffactor.o init.o monoMDS.o nestedness.o ordering.o pnpoly.o stepacross.o vegdist.o -llapack -lblas -lgfortran -lm -lquadmath -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR
# installing to /dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/00LOCK-vegan/00new/vegan/libs
# ** R
# ** data
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (vegan)
# * installing *source* package ‘dcurver’ ...
# ** package ‘dcurver’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘g++ (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609’
# using C++11
# g++ -std=gnu++11 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp  -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c RcppExports.cpp -o RcppExports.o
# g++ -std=gnu++11 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp  -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c dcUtils.cpp -o dcUtils.o
# g++ -std=gnu++11 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp  -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c distFuncs.cpp -o distFuncs.o
# g++ -std=gnu++11 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp  -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c estFuncs.cpp -o estFuncs.o
# g++ -std=gnu++11 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o dcurver.so RcppExports.o dcUtils.o distFuncs.o estFuncs.o -fopenmp -llapack -lblas -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR
# installing to /dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/00LOCK-dcurver/00new/dcurver/libs
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (dcurver)
# * installing *source* package ‘mirt’ ...
# ** package ‘mirt’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘g++ (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609’
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c Estep.cpp -o Estep.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c Misc.cpp -o Misc.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c dpars.cpp -o dpars.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c ggum_derivs.cpp -o ggum_derivs.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/usr/local/lib/R/site-library/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'    -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c traceLinePts.cpp -o traceLinePts.o
# g++ -std=gnu++14 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o mirt.so Estep.o Misc.o dpars.o ggum_derivs.o traceLinePts.o -llapack -lblas -lgfortran -lm -lquadmath -fopenmp -L/usr/lib/R/lib -lR
# installing to /dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/00LOCK-mirt/00new/mirt/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# Creating a new generic function for ‘Deriv’ in package ‘mirt’
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (mirt)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmp2WMD6G/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Installing package into ‘/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3’
# (as ‘lib’ is unspecified)
#
# R[write to console]: also installing the dependencies ‘fs’, ‘rappdirs’, ‘Rcpp’, ‘base64enc’, ‘jquerylib’, ‘memoise’, ‘sass’, ‘httpuv’, ‘mime’, ‘jsonlite’, ‘xtable’, ‘fontawesome’, ‘htmltools’, ‘sourcetools’, ‘later’, ‘promises’, ‘rlang’, ‘fastmap’, ‘commonmark’, ‘bslib’, ‘cachem’, ‘xfun’, ‘shiny’, ‘markdown’, ‘lpSolve’
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/fs_1.6.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1185603 bytes (1.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.1 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/rappdirs_0.3.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 12288 bytes (12 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 12 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/Rcpp_1.0.11.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2994004 bytes (2.9 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.9 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/base64enc_0.1-3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 7833 bytes
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 7833 bytes
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/jquerylib_0.1.4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 520207 bytes (508 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 508 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/memoise_2.0.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 17852 bytes (17 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 17 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/sass_0.4.7.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3025460 bytes (2.9 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.9 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/httpuv_1.6.12.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1879118 bytes (1.8 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.8 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/mime_0.12.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 12562 bytes (12 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 12 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/jsonlite_1.8.7.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1053075 bytes (1.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.0 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/xtable_1.8-4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 564589 bytes (551 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 551 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/fontawesome_0.5.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1281884 bytes (1.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.2 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/htmltools_0.5.7.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 134681 bytes (131 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 131 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/sourcetools_0.1.7-1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 24095 bytes (23 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 23 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/later_1.3.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 63641 bytes (62 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c http.cpp -o http.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c httprequest.cpp -o httprequest.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c httpresponse.cpp -o httpresponse.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c httpuv.cpp -o httpuv.o
# gcc -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c md5.c -o md5.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c mime.cpp -o mime.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c socket.cpp -o socket.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c staticpath.cpp -o staticpath.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c thread.cpp -o thread.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c timegm.cpp -o timegm.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c utils.cpp -o utils.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c uvutil.cpp -o uvutil.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c webapplication.cpp -o webapplication.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c websockets-base.cpp -o websockets-base.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c websockets-hixie76.cpp -o websockets-hixie76.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c websockets-hybi03.cpp -o websockets-hybi03.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c websockets-ietf.cpp -o websockets-ietf.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c websockets.cpp -o websockets.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c winutils.cpp -o winutils.o
# cp -p -f libuv/m4/lt_obsolete.m4 libuv/m4/lt~obsolete.m4
# cd libuv; \
# if ! command -v automake >/dev/null 2>&1 ; then \
# 	echo "automake not found. Touching files so configure will not try to run automake."; \
# 	touch aclocal.m4; \
# 	touch -r aclocal.m4 configure Makefile.in; \
# else \
# 	echo "automake found. Running autoupdate and autogen.sh."; \
# 	autoupdate; \
# 	sh autogen.sh; \
# fi; \
# chmod +x configure; \
# CC="gcc" CFLAGS="-g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -fpic -fvisibility=hidden -DNDEBUG" CPPFLAGS="" AR="ar" RANLIB="ranlib" LDFLAGS="-Wl,-Bsymbolic-functions -Wl,-z,relro" ./configure "--quiet"
# automake found. Running autoupdate and autogen.sh.
# aclocal.m4:17: warning: this file was generated for autoconf 2.71.
# You have another version of autoconf.  It may work, but is not guaranteed to.
# If you have problems, you may need to regenerate the build system entirely.
# To do so, use the procedure documented by the package, typically 'autoreconf'.
# + libtoolize --copy
# /opt/miniconda3/bin/libtoolize: 1: /opt/miniconda3/bin/libtoolize: /usr/bin/grep: not found
# libtoolize: warning: no serial number on '/opt/miniconda3/share/aclocal/libtool.m4', not copying.
# libtoolize: putting auxiliary files in '.'.
# libtoolize: copying file './ltmain.sh'
# libtoolize: putting macros in 'm4'.
# libtoolize: copying file 'm4/libtool.m4'
# libtoolize: copying file 'm4/ltversion.m4'
# + aclocal -I m4
# + autoconf
# + automake --add-missing --copy
# make --directory=libuv \
# 	HAVE_DTRACE=0
# make[1]: Entering directory '/tmp/RtmpXk0o2u/R.INSTALLcc3e3f20c96c/httpuv/src/libuv'
#   CC       src/libuv_la-fs-poll.lo
#   CC       src/libuv_la-idna.lo
#   CC       src/libuv_la-inet.lo
#   CC       src/libuv_la-random.lo
#   CC       src/libuv_la-strscpy.lo
#   CC       src/libuv_la-threadpool.lo
#   CC       src/libuv_la-timer.lo
#   CC       src/libuv_la-uv-data-getter-setters.lo
#   CC       src/libuv_la-uv-common.lo
#   CC       src/libuv_la-version.lo
#   CC       src/unix/libuv_la-async.lo
#   CC       src/unix/libuv_la-core.lo
#   CC       src/unix/libuv_la-dl.lo
#   CC       src/unix/libuv_la-fs.lo
#   CC       src/unix/libuv_la-getaddrinfo.lo
#   CC       src/unix/libuv_la-getnameinfo.lo
#   CC       src/unix/libuv_la-loop-watcher.lo
#   CC       src/unix/libuv_la-loop.lo
#   CC       src/unix/libuv_la-pipe.lo
#   CC       src/unix/libuv_la-poll.lo
#   CC       src/unix/libuv_la-process.lo
#   CC       src/unix/libuv_la-random-devurandom.lo
#   CC       src/unix/libuv_la-signal.lo
#   CC       src/unix/libuv_la-stream.lo
#   CC       src/unix/libuv_la-tcp.lo
#   CC       src/unix/libuv_la-thread.lo
#   CC       src/unix/libuv_la-tty.lo
#   CC       src/unix/libuv_la-udp.lo
#   CC       src/unix/libuv_la-linux-core.lo
#   CC       src/unix/libuv_la-linux-inotify.lo
#   CC       src/unix/libuv_la-linux-syscalls.lo
#   CC       src/unix/libuv_la-procfs-exepath.lo
#   CC       src/unix/libuv_la-proctitle.lo
#   CC       src/unix/libuv_la-random-getrandom.lo
#   CC       src/unix/libuv_la-random-sysctl-linux.lo
#   CC       src/unix/libuv_la-epoll.lo
#   CCLD     libuv.la
# make[1]: Leaving directory '/tmp/RtmpXk0o2u/R.INSTALLcc3e3f20c96c/httpuv/src/libuv'
# gcc -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c http-parser/http_parser.c -o http-parser/http_parser.o
# gcc -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c sha1/sha1.c -o sha1/sha1.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG -Ilibuv/include -pthread -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/later/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include'    -fvisibility=hidden -DSTRICT_R_HEADERS -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c base64/base64.cpp -o base64/base64.o
# g++ -std=gnu++14 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o httpuv.so RcppExports.o callback.o callbackqueue.o filedatasource-unix.o filedatasource-win.o fs.o gzipdatasource.o http.o httprequest.o httpresponse.o httpuv.o md5.o mime.o socket.o staticpath.o thread.o timegm.o utils.o uvutil.o webapplication.o websockets-base.o websockets-hixie76.o websockets-hybi03.o websockets-ietf.o websockets.o winutils.o ./libuv/.libs/libuv.a ./http-parser/http_parser.o ./sha1/sha1.o ./base64/base64.o -pthread -L/usr/lib/R/lib -lR
# installing to /dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/00LOCK-httpuv/00new/httpuv/libs
# ** R
# ** demo
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (httpuv)
# * installing *source* package ‘bslib’ ...
# ** package ‘bslib’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (bslib)
# * installing *source* package ‘shiny’ ...
# ** package ‘shiny’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (shiny)
# * installing *source* package ‘mirtCAT’ ...
# ** package ‘mirtCAT’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘g++ (Ubuntu 5.4.0-6ubuntu1~16.04.12) 5.4.0 20160609’
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'     -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c CAT_functions.cpp -o CAT_functions.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/RcppArmadillo/include'     -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c item_functions.cpp -o item_functions.o
# g++ -std=gnu++14 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o mirtCAT.so CAT_functions.o item_functions.o -llapack -lblas -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR
# installing to /dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.3/00LOCK-mirtCAT/00new/mirtCAT/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (mirtCAT)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmp2WMD6G/downloaded_packages’
# R[write to console]:
# R[write to console]:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7fe2f6999d80> [RTYPES.NILSXP]

# %%
mirt = importr('mirt')
mirtcat = importr("mirtCAT")

# %% [markdown]
# ## Examinando Motivo Aban

# %%
ano = 2019
item_info = pd.read_csv(f'../inep/enem/{ano}/DADOS/ITENS_PROVA_{ano}-utf8.csv',sep='\;',engine='python')
item_info.value_counts('TX_MOTIVO_ABAN')
# Out:
# TX_MOTIVO_ABAN
# Não permitiu a convergência do algoritmo de estimação da TRI    38
# Name: count, dtype: int64

# %%
item_info.query('IN_ITEM_ABAN == 1')
# Out:
#       CO_POSICAO SG_AREA  CO_ITEM TX_GABARITO  CO_HABILIDADE  IN_ITEM_ABAN  \
# 219           15      LC   118260           E             15             1
# 371           29      LC   118260           E             15             1
# 372           29      LC   118260           E             15             1
# 373           29      LC   118260           E             15             1
# 416           33      LC   118260           E             15             1
# 450           36      LC   118260           E             15             1
# 582           48      CH   118067           C             29             1
# 770           66      CH    76955           B             27             1
# 813           69      CH   118067           C             29             1
# 841           72      CH    76955           B             27             1
# 879           75      CH   118067           C             29             1
# 903           78      CH    76955           B             27             1
# 904           78      CH    76955           B             27             1
# 905           78      CH    76955           B             27             1
# 943           81      CH   118067           C             29             1
# 944           81      CH   118067           C             29             1
# 945           81      CH   118067           C             29             1
# 1037          90      CH    76955           B             27             1
# 1121          98      CN    83609           E             18             1
# 1126          99      CN    42605           B              6             1
# 1190         105      CN    42605           B              6             1
# 1207         107      CN    83609           E             18             1
# 1208         107      CN    83609           E             18             1
# 1209         107      CN    83609           E             18             1
# 1339         120      CN    42605           B              6             1
# 1361         122      CN    83609           E             18             1
# 1429         129      CN    42605           B              6             1
# 1430         129      CN    83609           E             18             1
# 1546         141      MT    23065           C             14             1
# 1547         141      MT    23065           C             14             1
# 1548         141      MT    23065           C             14             1
# 1578         144      MT    28698           C              3             1
# 1585         145      MT    23065           C             14             1
# 1627         149      MT    23065           C             14             1
# 1668         153      MT    23065           C             14             1
# 1738         160      MT    28698           C              3             1
# 1798         166      MT    28698           C              3             1
# 1877         174      MT    28698           C              3             1
#
#                                          TX_MOTIVO_ABAN  NU_PARAM_A  \
# 219   Não permitiu a convergência do algoritmo de es...         NaN
# 371   Não permitiu a convergência do algoritmo de es...         NaN
# 372   Não permitiu a convergência do algoritmo de es...         NaN
# 373   Não permitiu a convergência do algoritmo de es...         NaN
# 416   Não permitiu a convergência do algoritmo de es...         NaN
# 450   Não permitiu a convergência do algoritmo de es...         NaN
# 582   Não permitiu a convergência do algoritmo de es...         NaN
# 770   Não permitiu a convergência do algoritmo de es...         NaN
# 813   Não permitiu a convergência do algoritmo de es...         NaN
# 841   Não permitiu a convergência do algoritmo de es...         NaN
# 879   Não permitiu a convergência do algoritmo de es...         NaN
# 903   Não permitiu a convergência do algoritmo de es...         NaN
# 904   Não permitiu a convergência do algoritmo de es...         NaN
# 905   Não permitiu a convergência do algoritmo de es...         NaN
# 943   Não permitiu a convergência do algoritmo de es...         NaN
# 944   Não permitiu a convergência do algoritmo de es...         NaN
# 945   Não permitiu a convergência do algoritmo de es...         NaN
# 1037  Não permitiu a convergência do algoritmo de es...         NaN
# 1121  Não permitiu a convergência do algoritmo de es...         NaN
# 1126  Não permitiu a convergência do algoritmo de es...         NaN
# 1190  Não permitiu a convergência do algoritmo de es...         NaN
# 1207  Não permitiu a convergência do algoritmo de es...         NaN
# 1208  Não permitiu a convergência do algoritmo de es...         NaN
# 1209  Não permitiu a convergência do algoritmo de es...         NaN
# 1339  Não permitiu a convergência do algoritmo de es...         NaN
# 1361  Não permitiu a convergência do algoritmo de es...         NaN
# 1429  Não permitiu a convergência do algoritmo de es...         NaN
# 1430  Não permitiu a convergência do algoritmo de es...         NaN
# 1546  Não permitiu a convergência do algoritmo de es...         NaN
# 1547  Não permitiu a convergência do algoritmo de es...         NaN
# 1548  Não permitiu a convergência do algoritmo de es...         NaN
# 1578  Não permitiu a convergência do algoritmo de es...         NaN
# 1585  Não permitiu a convergência do algoritmo de es...         NaN
# 1627  Não permitiu a convergência do algoritmo de es...         NaN
# 1668  Não permitiu a convergência do algoritmo de es...         NaN
# 1738  Não permitiu a convergência do algoritmo de es...         NaN
# 1798  Não permitiu a convergência do algoritmo de es...         NaN
# 1877  Não permitiu a convergência do algoritmo de es...         NaN
#
#       NU_PARAM_B  NU_PARAM_C   TX_COR  CO_PROVA  TP_LINGUA  IN_ITEM_ADAPTADO
# 219          NaN         NaN   Branca       514        NaN                 0
# 371          NaN         NaN  Amarela       512        NaN                 0
# 372          NaN         NaN  Laranja       521        NaN                 0
# 373          NaN         NaN    Verde       525        NaN                 1
# 416          NaN         NaN     Azul       511        NaN                 0
# 450          NaN         NaN     Rosa       513        NaN                 0
# 582          NaN         NaN     Azul       507        NaN                 0
# 770          NaN         NaN   Branca       509        NaN                 0
# 813          NaN         NaN   Branca       509        NaN                 0
# 841          NaN         NaN     Rosa       510        NaN                 0
# 879          NaN         NaN     Rosa       510        NaN                 0
# 903          NaN         NaN  Amarela       508        NaN                 0
# 904          NaN         NaN  Laranja       520        NaN                 0
# 905          NaN         NaN    Verde       524        NaN                 1
# 943          NaN         NaN  Amarela       508        NaN                 0
# 944          NaN         NaN  Laranja       520        NaN                 0
# 945          NaN         NaN    Verde       524        NaN                 1
# 1037         NaN         NaN     Azul       507        NaN                 0
# 1121         NaN         NaN  Amarela       504        NaN                 0
# 1126         NaN         NaN     Rosa       546        NaN                 0
# 1190         NaN         NaN    Cinza       544        NaN                 0
# 1207         NaN         NaN    Cinza       505        NaN                 0
# 1208         NaN         NaN  Laranja       519        NaN                 0
# 1209         NaN         NaN    Verde       523        NaN                 1
# 1339         NaN         NaN  Amarela       543        NaN                 0
# 1361         NaN         NaN     Azul       503        NaN                 0
# 1429         NaN         NaN     Azul       545        NaN                 0
# 1430         NaN         NaN     Rosa       506        NaN                 0
# 1546         NaN         NaN    Cinza       518        NaN                 0
# 1547         NaN         NaN  Laranja       522        NaN                 0
# 1548         NaN         NaN    Verde       526        NaN                 1
# 1578         NaN         NaN  Amarela       555        NaN                 0
# 1585         NaN         NaN     Azul       515        NaN                 0
# 1627         NaN         NaN  Amarela       516        NaN                 0
# 1668         NaN         NaN     Rosa       517        NaN                 0
# 1738         NaN         NaN     Rosa       558        NaN                 0
# 1798         NaN         NaN     Azul       557        NaN                 0
# 1877         NaN         NaN    Cinza       556        NaN                 0

# %%
def load_acertos(ano,area,perc=1,sample=None,remove_abandonados=True):
    '''Retorna os acertos original (da amostra de x %) com os itens mais colunos com as notas_inep e caderno.
     Também retorna e um com somente itens.
    
    Se usar sample, retornar somente sample linhas. Deve dar erro se sample > número de linhas na amostra'''
    df = pd.read_csv(f'data/ac_{perc}_{ano}_{area}.csv',index_col='candidato')
    if sample:
        df = df.sample(sample)
    resp = df.iloc[:,:-3] # assume que as últimas 3 colunas são acertos, nota_inep e caderno 
    if remove_abandonados:
        removed_columns = [col for col in resp.columns if col.endswith('-aban')]
        resp = resp.drop(columns=removed_columns)

    item_info = pd.read_csv(f'../inep/enem/{ano}/DADOS/ITENS_PROVA_{ano}-utf8.csv',sep='\;',engine='python')
    item_info.dropna(subset='CO_ITEM',inplace=True)
    item_info['CO_ITEM'] = item_info['CO_ITEM'].astype(int)
    item_info = item_info[item_info['SG_AREA'] == area]
    item_info = item_info.drop_duplicates(subset='CO_ITEM')
    return df,resp,item_info

df,resp,item_info = load_acertos(2009,'CN',sample=10000,remove_abandonados=False)
resp
# Out:
#               60083  60084  60085  60086  60087  60088  60089  60090  59286  \
# candidato
# 100001070944      0      0      0      1      1      1      1      0      0
# 100003053398      1      0      0      1      1      1      1      0      0
# 100003881375      1      1      0      1      0      1      0      0      1
# 100000310757      1      1      1      0      0      0      0      0      0
# 100000762755      1      0      0      1      1      0      0      0      0
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 100001260552      1      0      1      0      1      1      1      0      0
# 100001352617      1      0      1      1      1      0      1      0      0
# 100000483925      1      0      0      0      1      1      1      0      0
# 100003441110      1      1      0      1      1      1      1      1      1
# 100001856673      1      0      0      1      0      0      1      0      0
#
#               60091  ...  60145  60146  60147  58396  59311  60148  60149  \
# candidato            ...
# 100001070944      0  ...      0      1      0      0      1      0      0
# 100003053398      0  ...      0      1      0      0      1      1      1
# 100003881375      0  ...      0      0      0      0      1      0      1
# 100000310757      0  ...      0      0      0      0      1      0      1
# 100000762755      0  ...      0      0      0      0      1      0      0
# ...             ...  ...    ...    ...    ...    ...    ...    ...    ...
# 100001260552      0  ...      0      1      0      0      0      0      1
# 100001352617      0  ...      0      0      0      0      0      1      0
# 100000483925      0  ...      0      1      0      1      0      1      0
# 100003441110      0  ...      0      0      0      0      1      0      0
# 100001856673      0  ...      0      0      0      0      0      0      0
#
#               60150  60151  60152
# candidato
# 100001070944      0      0      1
# 100003053398      0      0      0
# 100003881375      0      0      0
# 100000310757      0      0      1
# 100000762755      0      0      0
# ...             ...    ...    ...
# 100001260552      0      0      0
# 100001352617      0      0      0
# 100000483925      1      0      0
# 100003441110      0      0      1
# 100001856673      0      0      0
#
# [10000 rows x 45 columns]

# %%
def rename_aban(itemname):
    return itemname.strip('-aban')

def item_stats(ano,area):
    acertos, resp, item_info = load_acertos(ano, area, sample=10000,remove_abandonados=False)
    resp.rename(columns=rename_aban,inplace=True)
    istats = mirt.itemstats(to_rdf(resp))
    istats = to_df(istats[1])
    #istats.index = istats.index.astype(int)
    #istats.index = istats.index
    item_info = item_info.drop_duplicates(subset=['CO_ITEM'],keep='first')
    item_info = item_info.set_index('CO_ITEM')
    item_info.index = item_info.index.astype(str)
    istats = pd.merge(istats,item_info,how='left',left_index=True,right_index=True,validate='1:m')
    istats = istats.drop(columns=['CO_HABILIDADE'])
    return istats
istats = item_stats(2019,'CN')
istats.sort_values('total.r',ascending=True)
# Out:
#             N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 14273   10000  0.0923  0.289463  0.010440      -0.048881     0.652510
# 97169   10000  0.1278  0.333884  0.040291      -0.028210     0.652548
# 111601  10000  0.2264  0.418522  0.067542      -0.018347     0.654036
# 54381   10000  0.1133  0.316975  0.071511       0.006507     0.650491
# 83441   10000  0.1300  0.336320  0.079520       0.010564     0.650610
# 83609   10000  0.3086  0.461939  0.086877      -0.007909     0.654482
# 78504   10000  0.1960  0.396988  0.112653       0.031404     0.650473
# 49600   10000  0.1714  0.376877  0.116605       0.039537     0.649668
# 117868  10000  0.4955  0.500005  0.121435       0.019008     0.653498
# 89515   10000  0.3195  0.466306  0.140687       0.045440     0.650801
# 111545  10000  0.2559  0.436388  0.149838       0.060898     0.649218
# 117746  10000  0.1632  0.369567  0.154164       0.079056     0.647309
# 117883  10000  0.2461  0.430759  0.160028       0.072412     0.648369
# 111705  10000  0.2271  0.418979  0.160532       0.075353     0.648031
# 81478   10000  0.2447  0.429931  0.161133       0.073707     0.648273
# 117979  10000  0.3050  0.460430  0.161337       0.067623     0.649118
# 7629    10000  0.2786  0.448333  0.173152       0.082154     0.647931
# 84568   10000  0.2857  0.451770  0.188114       0.096723     0.646955
# 19407   10000  0.1813  0.385286  0.189781       0.112088     0.645474
# 117875  10000  0.1812  0.385203  0.191316       0.113672     0.645378
# 83526   10000  0.2195  0.413929  0.192067       0.108546     0.645843
# 82364   10000  0.2933  0.455298  0.215369       0.123943     0.645065
# 55328   10000  0.3697  0.482748  0.215709       0.118653     0.645661
# 96556   10000  0.2467  0.431112  0.217461       0.131052     0.644450
# 89772   10000  0.2344  0.423644  0.221880       0.137122     0.644022
# 82236   10000  0.1817  0.385616  0.232913       0.156220     0.642820
# 24104   10000  0.2361  0.424706  0.249494       0.165369     0.642147
# 117836  10000  0.1885  0.391130  0.281483       0.205266     0.639790
# 117642  10000  0.3509  0.477276  0.287613       0.194305     0.639951
# 82490   10000  0.3411  0.474103  0.301215       0.209166     0.638847
# 117890  10000  0.2544  0.435545  0.302865       0.218626     0.638471
# 89298   10000  0.4123  0.492273  0.307547       0.212149     0.638515
# 111624  10000  0.5085  0.499953  0.313138       0.216478     0.638132
# 39290   10000  0.3389  0.473359  0.346330       0.256766     0.635266
# 85548   10000  0.2914  0.454430  0.353963       0.268555     0.634681
# 31718   10000  0.4170  0.493088  0.355620       0.262709     0.634536
# 86521   10000  0.4550  0.497996  0.361268       0.267738     0.634069
# 88853   10000  0.3393  0.473495  0.368145       0.279844     0.633513
# 117988  10000  0.2257  0.418063  0.398470       0.322709     0.631700
# 29776   10000  0.4971  0.500017  0.413275       0.322928     0.629587
# 60311   10000  0.4706  0.499160  0.423565       0.334167     0.628696
# 7529    10000  0.4100  0.491858  0.431146       0.343718     0.628117
# 19223   10000  0.4999  0.500025  0.433560       0.344786     0.627810
# 89150   10000  0.3960  0.489089  0.455227       0.370268     0.626073
# 117999  10000  0.3219  0.467228  0.488894       0.410798     0.623679
#
#         CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN  \
# 14273          106      CN           D             0
# 97169          107      CN           A             0
# 111601          91      CN           B             0
# 54381           96      CN           A             0
# 83441          106      CN           D             0
# 83609           98      CN           E             1
# 78504          108      CN           C             0
# 49600          108      CN           D             0
# 117868         114      CN           E             0
# 89515          113      CN           C             0
# 111545          92      CN           E             0
# 117746          95      CN           A             0
# 117883         102      CN           B             0
# 111705          97      CN           B             0
# 81478           98      CN           B             0
# 117979          97      CN           B             0
# 7629           109      CN           B             0
# 84568           94      CN           C             0
# 19407           93      CN           E             0
# 117875          91      CN           D             0
# 83526           99      CN           C             0
# 82364           91      CN           A             0
# 55328          112      CN           B             0
# 96556          109      CN           A             0
# 89772           95      CN           C             0
# 82236          105      CN           D             0
# 24104           96      CN           E             0
# 117836          92      CN           A             0
# 117642          92      CN           A             0
# 82490          103      CN           C             0
# 117890          95      CN           B             0
# 89298          111      CN           A             0
# 111624         104      CN           D             0
# 39290          110      CN           E             0
# 85548           93      CN           D             0
# 31718           91      CN           D             0
# 86521           96      CN           C             0
# 88853          101      CN           C             0
# 117988          93      CN           A             0
# 29776           93      CN           E             0
# 60311           99      CN           E             0
# 7529            94      CN           D             0
# 19223          107      CN           B             0
# 89150           92      CN           E             0
# 117999          94      CN           C             0
#
#                                            TX_MOTIVO_ABAN  NU_PARAM_A  \
# 14273                                                 NaN     3.90297
# 97169                                                 NaN     5.93339
# 111601                                                NaN     7.09582
# 54381                                                 NaN     3.20714
# 83441                                                 NaN     4.60881
# 83609   Não permitiu a convergência do algoritmo de es...         NaN
# 78504                                                 NaN     3.20779
# 49600                                                 NaN     1.14904
# 117868                                                NaN     0.05808
# 89515                                                 NaN     3.14647
# 111545                                                NaN     0.54124
# 117746                                                NaN     1.21390
# 117883                                                NaN     0.38139
# 111705                                                NaN     1.78669
# 81478                                                 NaN     2.37739
# 117979                                                NaN     1.19339
# 7629                                                  NaN     0.75316
# 84568                                                 NaN     2.42831
# 19407                                                 NaN     2.32962
# 117875                                                NaN     1.78539
# 83526                                                 NaN     1.62997
# 82364                                                 NaN     2.43167
# 55328                                                 NaN     0.54974
# 96556                                                 NaN     1.66258
# 89772                                                 NaN     0.67587
# 82236                                                 NaN     2.77263
# 24104                                                 NaN     3.41094
# 117836                                                NaN     1.87838
# 117642                                                NaN     1.92967
# 82490                                                 NaN     1.75058
# 117890                                                NaN     1.85268
# 89298                                                 NaN     1.02022
# 111624                                                NaN     1.03081
# 39290                                                 NaN     2.00073
# 85548                                                 NaN     2.96175
# 31718                                                 NaN     1.90483
# 86521                                                 NaN     1.71979
# 88853                                                 NaN     2.39212
# 117988                                                NaN     3.11909
# 29776                                                 NaN     2.80865
# 60311                                                 NaN     2.79351
# 7529                                                  NaN     2.26543
# 19223                                                 NaN     2.06769
# 89150                                                 NaN     3.48200
# 117999                                                NaN     3.76618
#
#         NU_PARAM_B  NU_PARAM_C   TX_COR  CO_PROVA  TP_LINGUA  IN_ITEM_ADAPTADO
# 14273      2.19782     0.05798  Amarela       504        NaN                 0
# 97169      1.98881     0.13188  Amarela       504        NaN                 0
# 111601     2.42384     0.23686  Amarela       504        NaN                 0
# 54381      2.14905     0.08067     Rosa       506        NaN                 0
# 83441      1.94111     0.12462     Azul       503        NaN                 0
# 83609          NaN         NaN  Amarela       504        NaN                 0
# 78504      1.67408     0.16383     Azul       503        NaN                 0
# 49600      2.36402     0.11480  Amarela       504        NaN                 0
# 117868     8.96186     0.22071  Amarela       504        NaN                 0
# 89515      1.67856     0.32644  Amarela       504        NaN                 0
# 111545     3.79854     0.17374  Amarela       504        NaN                 0
# 117746     2.21432     0.09924     Azul       503        NaN                 0
# 117883     3.36471     0.06869     Azul       503        NaN                 0
# 111705     1.78124     0.20473    Cinza       505        NaN                 0
# 81478      1.59193     0.20921    Cinza       505        NaN                 0
# 117979     2.04675     0.26041  Amarela       504        NaN                 0
# 7629       1.83643     0.10672     Azul       503        NaN                 0
# 84568      1.66707     0.29842    Cinza       505        NaN                 0
# 19407      1.67314     0.14993  Amarela       504        NaN                 0
# 117875     1.58564     0.13602    Cinza       505        NaN                 0
# 83526      1.70518     0.16280    Cinza       505        NaN                 0
# 82364      1.13773     0.22233     Azul       503        NaN                 0
# 55328      0.97948     0.05877  Amarela       504        NaN                 0
# 96556      1.37670     0.17468  Amarela       504        NaN                 0
# 89772      1.59601     0.02169    Cinza       505        NaN                 0
# 82236      1.28601     0.13618     Azul       503        NaN                 0
# 24104      1.15715     0.16829    Cinza       505        NaN                 0
# 117836     1.45214     0.07496     Azul       503        NaN                 0
# 117642     1.07472     0.22014    Cinza       505        NaN                 0
# 82490      1.02204     0.23374     Azul       503        NaN                 0
# 117890     0.99689     0.12401     Rosa       506        NaN                 0
# 89298      0.29761     0.01670  Amarela       504        NaN                 0
# 111624    -0.00312     0.01163     Azul       503        NaN                 0
# 39290      0.86840     0.16452  Amarela       504        NaN                 0
# 85548      0.58267     0.11175    Cinza       505        NaN                 0
# 31718      0.48421     0.21286     Rosa       506        NaN                 0
# 86521      0.25498     0.14498     Azul       503        NaN                 0
# 88853      0.70901     0.16500     Azul       503        NaN                 0
# 117988     0.80483     0.08561     Rosa       506        NaN                 0
# 29776      0.58402     0.21207     Azul       503        NaN                 0
# 60311      0.15609     0.14102  Amarela       504        NaN                 0
# 7529       0.62256     0.16620     Rosa       506        NaN                 0
# 19223     -0.11974     0.19742     Azul       503        NaN                 0
# 89150      0.29664     0.15617     Rosa       506        NaN                 0
# 117999     0.41535     0.10709     Azul       503        NaN                 0

# %%
istats.sort_values(by=['TX_MOTIVO_ABAN'])
# Out:
#             N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 83609   10000  0.3086  0.461939  0.086877      -0.007909     0.654482
# 31718   10000  0.4170  0.493088  0.355620       0.262709     0.634536
# 89150   10000  0.3960  0.489089  0.455227       0.370268     0.626073
# 117988  10000  0.2257  0.418063  0.398470       0.322709     0.631700
# 7529    10000  0.4100  0.491858  0.431146       0.343718     0.628117
# 117890  10000  0.2544  0.435545  0.302865       0.218626     0.638471
# 54381   10000  0.1133  0.316975  0.071511       0.006507     0.650491
# 82364   10000  0.2933  0.455298  0.215369       0.123943     0.645065
# 117836  10000  0.1885  0.391130  0.281483       0.205266     0.639790
# 29776   10000  0.4971  0.500017  0.413275       0.322928     0.629587
# 111601  10000  0.2264  0.418522  0.067542      -0.018347     0.654036
# 111545  10000  0.2559  0.436388  0.149838       0.060898     0.649218
# 19407   10000  0.1813  0.385286  0.189781       0.112088     0.645474
# 89772   10000  0.2344  0.423644  0.221880       0.137122     0.644022
# 24104   10000  0.2361  0.424706  0.249494       0.165369     0.642147
# 111705  10000  0.2271  0.418979  0.160532       0.075353     0.648031
# 88853   10000  0.3393  0.473495  0.368145       0.279844     0.633513
# 117883  10000  0.2461  0.430759  0.160028       0.072412     0.648369
# 82490   10000  0.3411  0.474103  0.301215       0.209166     0.638847
# 19223   10000  0.4999  0.500025  0.433560       0.344786     0.627810
# 78504   10000  0.1960  0.396988  0.112653       0.031404     0.650473
# 7629    10000  0.2786  0.448333  0.173152       0.082154     0.647931
# 14273   10000  0.0923  0.289463  0.010440      -0.048881     0.652510
# 97169   10000  0.1278  0.333884  0.040291      -0.028210     0.652548
# 49600   10000  0.1714  0.376877  0.116605       0.039537     0.649668
# 96556   10000  0.2467  0.431112  0.217461       0.131052     0.644450
# 39290   10000  0.3389  0.473359  0.346330       0.256766     0.635266
# 89298   10000  0.4123  0.492273  0.307547       0.212149     0.638515
# 55328   10000  0.3697  0.482748  0.215709       0.118653     0.645661
# 89515   10000  0.3195  0.466306  0.140687       0.045440     0.650801
# 117868  10000  0.4955  0.500005  0.121435       0.019008     0.653498
# 111624  10000  0.5085  0.499953  0.313138       0.216478     0.638132
# 82236   10000  0.1817  0.385616  0.232913       0.156220     0.642820
# 83441   10000  0.1300  0.336320  0.079520       0.010564     0.650610
# 117875  10000  0.1812  0.385203  0.191316       0.113672     0.645378
# 117642  10000  0.3509  0.477276  0.287613       0.194305     0.639951
# 85548   10000  0.2914  0.454430  0.353963       0.268555     0.634681
# 84568   10000  0.2857  0.451770  0.188114       0.096723     0.646955
# 117979  10000  0.3050  0.460430  0.161337       0.067623     0.649118
# 60311   10000  0.4706  0.499160  0.423565       0.334167     0.628696
# 117999  10000  0.3219  0.467228  0.488894       0.410798     0.623679
# 117746  10000  0.1632  0.369567  0.154164       0.079056     0.647309
# 86521   10000  0.4550  0.497996  0.361268       0.267738     0.634069
# 81478   10000  0.2447  0.429931  0.161133       0.073707     0.648273
# 83526   10000  0.2195  0.413929  0.192067       0.108546     0.645843
#
#         CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN  \
# 83609           98      CN           E             1
# 31718           91      CN           D             0
# 89150           92      CN           E             0
# 117988          93      CN           A             0
# 7529            94      CN           D             0
# 117890          95      CN           B             0
# 54381           96      CN           A             0
# 82364           91      CN           A             0
# 117836          92      CN           A             0
# 29776           93      CN           E             0
# 111601          91      CN           B             0
# 111545          92      CN           E             0
# 19407           93      CN           E             0
# 89772           95      CN           C             0
# 24104           96      CN           E             0
# 111705          97      CN           B             0
# 88853          101      CN           C             0
# 117883         102      CN           B             0
# 82490          103      CN           C             0
# 19223          107      CN           B             0
# 78504          108      CN           C             0
# 7629           109      CN           B             0
# 14273          106      CN           D             0
# 97169          107      CN           A             0
# 49600          108      CN           D             0
# 96556          109      CN           A             0
# 39290          110      CN           E             0
# 89298          111      CN           A             0
# 55328          112      CN           B             0
# 89515          113      CN           C             0
# 117868         114      CN           E             0
# 111624         104      CN           D             0
# 82236          105      CN           D             0
# 83441          106      CN           D             0
# 117875          91      CN           D             0
# 117642          92      CN           A             0
# 85548           93      CN           D             0
# 84568           94      CN           C             0
# 117979          97      CN           B             0
# 60311           99      CN           E             0
# 117999          94      CN           C             0
# 117746          95      CN           A             0
# 86521           96      CN           C             0
# 81478           98      CN           B             0
# 83526           99      CN           C             0
#
#                                            TX_MOTIVO_ABAN  NU_PARAM_A  \
# 83609   Não permitiu a convergência do algoritmo de es...         NaN
# 31718                                                 NaN     1.90483
# 89150                                                 NaN     3.48200
# 117988                                                NaN     3.11909
# 7529                                                  NaN     2.26543
# 117890                                                NaN     1.85268
# 54381                                                 NaN     3.20714
# 82364                                                 NaN     2.43167
# 117836                                                NaN     1.87838
# 29776                                                 NaN     2.80865
# 111601                                                NaN     7.09582
# 111545                                                NaN     0.54124
# 19407                                                 NaN     2.32962
# 89772                                                 NaN     0.67587
# 24104                                                 NaN     3.41094
# 111705                                                NaN     1.78669
# 88853                                                 NaN     2.39212
# 117883                                                NaN     0.38139
# 82490                                                 NaN     1.75058
# 19223                                                 NaN     2.06769
# 78504                                                 NaN     3.20779
# 7629                                                  NaN     0.75316
# 14273                                                 NaN     3.90297
# 97169                                                 NaN     5.93339
# 49600                                                 NaN     1.14904
# 96556                                                 NaN     1.66258
# 39290                                                 NaN     2.00073
# 89298                                                 NaN     1.02022
# 55328                                                 NaN     0.54974
# 89515                                                 NaN     3.14647
# 117868                                                NaN     0.05808
# 111624                                                NaN     1.03081
# 82236                                                 NaN     2.77263
# 83441                                                 NaN     4.60881
# 117875                                                NaN     1.78539
# 117642                                                NaN     1.92967
# 85548                                                 NaN     2.96175
# 84568                                                 NaN     2.42831
# 117979                                                NaN     1.19339
# 60311                                                 NaN     2.79351
# 117999                                                NaN     3.76618
# 117746                                                NaN     1.21390
# 86521                                                 NaN     1.71979
# 81478                                                 NaN     2.37739
# 83526                                                 NaN     1.62997
#
#         NU_PARAM_B  NU_PARAM_C   TX_COR  CO_PROVA  TP_LINGUA  IN_ITEM_ADAPTADO
# 83609          NaN         NaN  Amarela       504        NaN                 0
# 31718      0.48421     0.21286     Rosa       506        NaN                 0
# 89150      0.29664     0.15617     Rosa       506        NaN                 0
# 117988     0.80483     0.08561     Rosa       506        NaN                 0
# 7529       0.62256     0.16620     Rosa       506        NaN                 0
# 117890     0.99689     0.12401     Rosa       506        NaN                 0
# 54381      2.14905     0.08067     Rosa       506        NaN                 0
# 82364      1.13773     0.22233     Azul       503        NaN                 0
# 117836     1.45214     0.07496     Azul       503        NaN                 0
# 29776      0.58402     0.21207     Azul       503        NaN                 0
# 111601     2.42384     0.23686  Amarela       504        NaN                 0
# 111545     3.79854     0.17374  Amarela       504        NaN                 0
# 19407      1.67314     0.14993  Amarela       504        NaN                 0
# 89772      1.59601     0.02169    Cinza       505        NaN                 0
# 24104      1.15715     0.16829    Cinza       505        NaN                 0
# 111705     1.78124     0.20473    Cinza       505        NaN                 0
# 88853      0.70901     0.16500     Azul       503        NaN                 0
# 117883     3.36471     0.06869     Azul       503        NaN                 0
# 82490      1.02204     0.23374     Azul       503        NaN                 0
# 19223     -0.11974     0.19742     Azul       503        NaN                 0
# 78504      1.67408     0.16383     Azul       503        NaN                 0
# 7629       1.83643     0.10672     Azul       503        NaN                 0
# 14273      2.19782     0.05798  Amarela       504        NaN                 0
# 97169      1.98881     0.13188  Amarela       504        NaN                 0
# 49600      2.36402     0.11480  Amarela       504        NaN                 0
# 96556      1.37670     0.17468  Amarela       504        NaN                 0
# 39290      0.86840     0.16452  Amarela       504        NaN                 0
# 89298      0.29761     0.01670  Amarela       504        NaN                 0
# 55328      0.97948     0.05877  Amarela       504        NaN                 0
# 89515      1.67856     0.32644  Amarela       504        NaN                 0
# 117868     8.96186     0.22071  Amarela       504        NaN                 0
# 111624    -0.00312     0.01163     Azul       503        NaN                 0
# 82236      1.28601     0.13618     Azul       503        NaN                 0
# 83441      1.94111     0.12462     Azul       503        NaN                 0
# 117875     1.58564     0.13602    Cinza       505        NaN                 0
# 117642     1.07472     0.22014    Cinza       505        NaN                 0
# 85548      0.58267     0.11175    Cinza       505        NaN                 0
# 84568      1.66707     0.29842    Cinza       505        NaN                 0
# 117979     2.04675     0.26041  Amarela       504        NaN                 0
# 60311      0.15609     0.14102  Amarela       504        NaN                 0
# 117999     0.41535     0.10709     Azul       503        NaN                 0
# 117746     2.21432     0.09924     Azul       503        NaN                 0
# 86521      0.25498     0.14498     Azul       503        NaN                 0
# 81478      1.59193     0.20921    Cinza       505        NaN                 0
# 83526      1.70518     0.16280    Cinza       505        NaN                 0

# %%
for ano in range(2009, 2023):
    istats = item_stats(ano, 'CN')
    istats_sorted = istats.sort_values('total.r', ascending=True)
    
    non_nan_values = istats_sorted[istats_sorted['TX_MOTIVO_ABAN'].notna()]
    df_junto = pd.concat([non_nan_values,non_nan_values])
# Out:
#            N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 60141  10000  0.1559  0.362779 -0.006774      -0.073314     0.729989
# 60138  10000  0.1431  0.350192  0.040351      -0.024083     0.727797
#
#        CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN  \
# 60141          30      CN           E             1
# 60138          25      CN           D             1
#
#                                           TX_MOTIVO_ABAN  NU_PARAM_A  \
# 60141  Não permitiu a convergência do algoritmo de es...         NaN
# 60138  Não permitiu a convergência do algoritmo de es...         NaN
#
#        NU_PARAM_B  NU_PARAM_C   TX_COR  CO_PROVA
# 60141         NaN         NaN   BRANCO        51
# 60138         NaN         NaN  AMARELO        50
#            N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 73092  10000  0.1100  0.312905  0.021477      -0.032196     0.763079
# 59232  10000  0.1322  0.338725  0.026895      -0.031213     0.763501
# 72927  10000  0.2704  0.444189  0.081312       0.005123     0.764217
# 70145  10000  0.3390  0.473394  0.174815       0.094636     0.761013
#
#        CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN  \
# 73092          72      CN           E             1
# 59232          70      CN           A             1
# 72927          55      CN           C             1
# 70145          67      CN           D             1
#
#                                           TX_MOTIVO_ABAN  NU_PARAM_A  \
# 73092  Não permitiu a convergência do algoritmo de es...         NaN
# 59232  Não permitiu a convergência do algoritmo de es...         NaN
# 72927  Não permitiu a convergência do algoritmo de es...         NaN
# 70145  Não permitiu a convergência do algoritmo de es...         NaN
#
#        NU_PARAM_B  NU_PARAM_C TX_COR  CO_PROVA  TP_LINGUA
# 73092         NaN         NaN   Azul        89        NaN
# 59232         NaN         NaN   Azul        89        NaN
# 72927         NaN         NaN   Azul        89        NaN
# 70145         NaN         NaN   Azul        89        NaN
# Empty DataFrame
# Columns: [N, mean, sd, total.r, total.r_if_rm, alpha_if_rm, CO_POSICAO, SG_AREA, TX_GABARITO, IN_ITEM_ABAN, TX_MOTIVO_ABAN, NU_PARAM_A, NU_PARAM_B, NU_PARAM_C, TX_COR, CO_PROVA, TP_LINGUA]
# Index: []
# Empty DataFrame
# Columns: [N, mean, sd, total.r, total.r_if_rm, alpha_if_rm, CO_POSICAO, SG_AREA, TX_GABARITO, IN_ITEM_ABAN, TX_MOTIVO_ABAN, NU_PARAM_A, NU_PARAM_B, NU_PARAM_C, TX_COR, CO_PROVA, TP_LINGUA]
# Index: []
# Empty DataFrame
# Columns: [N, mean, sd, total.r, total.r_if_rm, alpha_if_rm, CO_POSICAO, SG_AREA, TX_GABARITO, IN_ITEM_ABAN, TX_MOTIVO_ABAN, NU_PARAM_A, NU_PARAM_B, NU_PARAM_C, TX_COR, CO_PROVA, TP_LINGUA, IN_ITEM_ADAPTADO]
# Index: []
#            N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 45270  10000  0.4592  0.498357  0.077223      -0.030971     0.622915
# 49314  10000  0.3784  0.485012  0.086611      -0.018678     0.621413
#
#        CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN  \
# 45270          53      CN           A             1
# 49314          51      CN           A             1
#
#                                           TX_MOTIVO_ABAN  NU_PARAM_A  \
# 45270  Não permitiu a convergência do algoritmo de es...         NaN
# 49314  Não permitiu a convergência do algoritmo de es...         NaN
#
#        NU_PARAM_B  NU_PARAM_C TX_COR  CO_PROVA  TP_LINGUA  IN_ITEM_ADAPTADO
# 45270         NaN         NaN   Azul       199        NaN               NaN
# 49314         NaN         NaN   Azul       199        NaN               NaN
# Empty DataFrame
# Columns: [N, mean, sd, total.r, total.r_if_rm, alpha_if_rm, CO_POSICAO, SG_AREA, TX_GABARITO, IN_ITEM_ABAN, TX_MOTIVO_ABAN, NU_PARAM_A, NU_PARAM_B, NU_PARAM_C, TX_COR, CO_PROVA, TP_LINGUA, IN_ITEM_ADAPTADO]
# Index: []
# Empty DataFrame
# Columns: [N, mean, sd, total.r, total.r_if_rm, alpha_if_rm, CO_POSICAO, SG_AREA, TX_GABARITO, IN_ITEM_ABAN, TX_MOTIVO_ABAN, NU_PARAM_A, NU_PARAM_B, NU_PARAM_C, TX_COR, CO_PROVA, TP_LINGUA, IN_ITEM_ADAPTADO]
# Index: []
# Empty DataFrame
# Columns: [N, mean, sd, total.r, total.r_if_rm, alpha_if_rm, CO_POSICAO, SG_AREA, TX_GABARITO, IN_ITEM_ABAN, TX_MOTIVO_ABAN, NU_PARAM_A, NU_PARAM_B, NU_PARAM_C, TX_COR, CO_PROVA, TP_LINGUA, IN_ITEM_ADAPTADO]
# Index: []
# Empty DataFrame
# Columns: [N, mean, sd, total.r, total.r_if_rm, alpha_if_rm, CO_POSICAO, SG_AREA, TX_GABARITO, IN_ITEM_ABAN, TX_MOTIVO_ABAN, NU_PARAM_A, NU_PARAM_B, NU_PARAM_C, TX_COR, CO_PROVA, TP_LINGUA, IN_ITEM_ADAPTADO]
# Index: []
#            N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 83609  10000  0.3079  0.461648  0.085498      -0.009154     0.655505
#
#        CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN  \
# 83609          98      CN           E             1
#
#                                           TX_MOTIVO_ABAN  NU_PARAM_A  \
# 83609  Não permitiu a convergência do algoritmo de es...         NaN
#
#        NU_PARAM_B  NU_PARAM_C   TX_COR  CO_PROVA  TP_LINGUA  IN_ITEM_ADAPTADO
# 83609         NaN         NaN  Amarela       504        NaN                 0
#            N  mean   sd  total.r  total.r_if_rm  alpha_if_rm  CO_POSICAO  \
# 32352  10000   0.0  0.0      NaN            NaN     0.742561         114
#
#       SG_AREA TX_GABARITO  IN_ITEM_ABAN TX_MOTIVO_ABAN  NU_PARAM_A  \
# 32352      CN           X             1        Anulado         NaN
#
#        NU_PARAM_B  NU_PARAM_C   TX_COR  CO_PROVA  TP_LINGUA  IN_ITEM_ADAPTADO  \
# 32352         NaN         NaN  AMARELA       598        NaN                 0
#
#        TP_VERSAO_DIGITAL
# 32352                NaN
#            N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 86378  10000  0.3678  0.482231  0.012434      -0.074168     0.735773
#
#        CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN  \
# 86378         118      CN           D             1
#
#                                           TX_MOTIVO_ABAN  NU_PARAM_A  \
# 86378  Não permitiu a convergência do algoritmo de es...         NaN
#
#        NU_PARAM_B  NU_PARAM_C TX_COR  CO_PROVA  TP_LINGUA  IN_ITEM_ADAPTADO
# 86378         NaN         NaN   AZUL       909        NaN               NaN
#             N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 64203   10000  0.1666  0.372637  0.022286      -0.060117     0.605365
# 89554   10000  0.1774  0.382026  0.051401      -0.033200     0.603766
# 75845   10000  0.2597  0.438492  0.052344      -0.044748     0.606428
# 141605  10000  0.3629  0.480860  0.081482      -0.025049     0.606181
#
#         CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN      TX_MOTIVO_ABAN  \
# 64203          119      CN           A             1      bisblg < -0.15
# 89554          112      CN           D             1       BLG não rodou
# 75845          134      CN           D             1       BLG não rodou
# 141605         113      CN           D             1  Bilog não converge
#
#         NU_PARAM_A  NU_PARAM_B  NU_PARAM_C TX_COR  CO_PROVA  TP_LINGUA  \
# 64203          NaN         NaN         NaN   AZUL      1085        NaN
# 89554          NaN         NaN         NaN   AZUL      1085        NaN
# 75845          NaN         NaN         NaN   AZUL      1085        NaN
# 141605         NaN         NaN         NaN   AZUL      1085        NaN
#
#         IN_ITEM_ADAPTADO
# 64203                  0
# 89554                  0
# 75845                  0
# 141605                 0

# %%
df_teste = pd.DataFrame(df_junto)
df_teste
# Out:
#             N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 64203   10000  0.1666  0.372637  0.022286      -0.060117     0.605365
# 89554   10000  0.1774  0.382026  0.051401      -0.033200     0.603766
# 75845   10000  0.2597  0.438492  0.052344      -0.044748     0.606428
# 141605  10000  0.3629  0.480860  0.081482      -0.025049     0.606181
# 64203   10000  0.1666  0.372637  0.022286      -0.060117     0.605365
# 89554   10000  0.1774  0.382026  0.051401      -0.033200     0.603766
# 75845   10000  0.2597  0.438492  0.052344      -0.044748     0.606428
# 141605  10000  0.3629  0.480860  0.081482      -0.025049     0.606181
#
#         CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN      TX_MOTIVO_ABAN  \
# 64203          119      CN           A             1      bisblg < -0.15
# 89554          112      CN           D             1       BLG não rodou
# 75845          134      CN           D             1       BLG não rodou
# 141605         113      CN           D             1  Bilog não converge
# 64203          119      CN           A             1      bisblg < -0.15
# 89554          112      CN           D             1       BLG não rodou
# 75845          134      CN           D             1       BLG não rodou
# 141605         113      CN           D             1  Bilog não converge
#
#         NU_PARAM_A  NU_PARAM_B  NU_PARAM_C TX_COR  CO_PROVA  TP_LINGUA  \
# 64203          NaN         NaN         NaN   AZUL      1085        NaN
# 89554          NaN         NaN         NaN   AZUL      1085        NaN
# 75845          NaN         NaN         NaN   AZUL      1085        NaN
# 141605         NaN         NaN         NaN   AZUL      1085        NaN
# 64203          NaN         NaN         NaN   AZUL      1085        NaN
# 89554          NaN         NaN         NaN   AZUL      1085        NaN
# 75845          NaN         NaN         NaN   AZUL      1085        NaN
# 141605         NaN         NaN         NaN   AZUL      1085        NaN
#
#         IN_ITEM_ADAPTADO
# 64203                  0
# 89554                  0
# 75845                  0
# 141605                 0
# 64203                  0
# 89554                  0
# 75845                  0
# 141605                 0

# %% [markdown]
# ### Podemos ver que a média do total r dos itens excluidos foi muito baixa se comparada a media dos itens totais, indicativo de que as questões era ruins mesmo e o maior valor das questões banidas foi de 0,081482, ainda sim um valor baixo

# %%
df_teste['total.r'].mean()
# Out:
# 0.051878277070909445

# %%
istats['total.r'].mean()
# Out:
# 0.22947013341787745

# %%
df_teste['total.r'].describe()
# Out:
# count    8.000000
# mean     0.051878
# std      0.022377
# min      0.022286
# 25%      0.044122
# 50%      0.051873
# 75%      0.059628
# max      0.081482
# Name: total.r, dtype: float64

# %% [markdown]
# ## Análise das questões com os piores índices total.r que não foram banidas

# %%
for ano in range(2009, 2023):
    istats = item_stats(ano, 'CN')
    
    df_todos_anos = pd.concat([istats,istats])
    df_todos_anos = df_todos_anos[df_todos_anos['TX_MOTIVO_ABAN'].isna()]

# %%
#selecionando as 10 piores questões
df_todos_anos.sort_values(by = "total.r").head(20)
# Out:
#             N    mean        sd   total.r  total.r_if_rm  alpha_if_rm  \
# 111694  10000  0.2229  0.416213  0.092411      -0.000966     0.590717
# 111694  10000  0.2229  0.416213  0.092411      -0.000966     0.590717
# 141731  10000  0.1271  0.333102  0.094754       0.020113     0.587465
# 141731  10000  0.1271  0.333102  0.094754       0.020113     0.587465
# 97915   10000  0.1989  0.399193  0.095736       0.006210     0.589739
# 97915   10000  0.1989  0.399193  0.095736       0.006210     0.589739
# 85860   10000  0.1755  0.380413  0.117257       0.032121     0.587393
# 85860   10000  0.1755  0.380413  0.117257       0.032121     0.587393
# 37769   10000  0.2718  0.444910  0.144214       0.044828     0.587479
# 37769   10000  0.2718  0.444910  0.144214       0.044828     0.587479
# 44969   10000  0.2629  0.440231  0.160668       0.062599     0.585855
# 44969   10000  0.2629  0.440231  0.160668       0.062599     0.585855
# 111668  10000  0.2329  0.422700  0.173744       0.079879     0.584171
# 111668  10000  0.2329  0.422700  0.173744       0.079879     0.584171
# 90130   10000  0.3186  0.465957  0.181538       0.078069     0.584821
# 90130   10000  0.3186  0.465957  0.181538       0.078069     0.584821
# 83901   10000  0.3023  0.459277  0.185441       0.083569     0.584236
# 83901   10000  0.3023  0.459277  0.185441       0.083569     0.584236
# 111558  10000  0.1685  0.374328  0.186686       0.103981     0.581981
# 111558  10000  0.1685  0.374328  0.186686       0.103981     0.581981
#
#         CO_POSICAO SG_AREA TX_GABARITO  IN_ITEM_ABAN TX_MOTIVO_ABAN  \
# 111694          94      CN           A             0            NaN
# 111694          94      CN           A             0            NaN
# 141731         102      CN           E             0            NaN
# 141731         102      CN           E             0            NaN
# 97915          106      CN           C             0            NaN
# 97915          106      CN           C             0            NaN
# 85860          107      CN           C             0            NaN
# 85860          107      CN           C             0            NaN
# 37769          121      CN           B             0            NaN
# 37769          121      CN           B             0            NaN
# 44969          108      CN           B             0            NaN
# 44969          108      CN           B             0            NaN
# 111668          93      CN           B             0            NaN
# 111668          93      CN           B             0            NaN
# 90130          100      CN           B             0            NaN
# 90130          100      CN           B             0            NaN
# 83901          126      CN           B             0            NaN
# 83901          126      CN           B             0            NaN
# 111558          95      CN           D             0            NaN
# 111558          95      CN           D             0            NaN
#
#         NU_PARAM_A  NU_PARAM_B  NU_PARAM_C TX_COR  CO_PROVA  TP_LINGUA  \
# 111694     2.07884     2.23408     0.17191   AZUL      1085        NaN
# 111694     2.07884     2.23408     0.17191   AZUL      1085        NaN
# 141731     1.52512     3.19204     0.11283   AZUL      1085        NaN
# 141731     1.52512     3.19204     0.11283   AZUL      1085        NaN
# 97915      2.39896     2.76588     0.18970   AZUL      1085        NaN
# 97915      2.39896     2.76588     0.18970   AZUL      1085        NaN
# 85860      5.31621     2.04288     0.17088   AZUL      1085        NaN
# 85860      5.31621     2.04288     0.17088   AZUL      1085        NaN
# 37769      1.78429     2.50062     0.27071   AZUL      1085        NaN
# 37769      1.78429     2.50062     0.27071   AZUL      1085        NaN
# 44969      3.07166     1.89127     0.25272   AZUL      1085        NaN
# 44969      3.07166     1.89127     0.25272   AZUL      1085        NaN
# 111668     1.98964     1.87763     0.19415   AZUL      1085        NaN
# 111668     1.98964     1.87763     0.19415   AZUL      1085        NaN
# 90130      1.73494     2.08841     0.27619   AZUL      1085        NaN
# 90130      1.73494     2.08841     0.27619   AZUL      1085        NaN
# 83901      0.40583     2.51676     0.00918   AZUL      1085        NaN
# 83901      0.40583     2.51676     0.00918   AZUL      1085        NaN
# 111558     3.29206     1.65709     0.14008   AZUL      1085        NaN
# 111558     3.29206     1.65709     0.14008   AZUL      1085        NaN
#
#         IN_ITEM_ADAPTADO
# 111694                 0
# 111694                 0
# 141731                 0
# 141731                 0
# 97915                  0
# 97915                  0
# 85860                  0
# 85860                  0
# 37769                  0
# 37769                  0
# 44969                  0
# 44969                  0
# 111668                 0
# 111668                 0
# 90130                  0
# 90130                  0
# 83901                  0
# 83901                  0
# 111558                 0
# 111558                 0

# %% [markdown]
# ## Resto

# %%
def load_model(ano,area,itemtype="3PL", method="EM", SE=True,remove_b=None):
    if remove_b:
        fn = f'data/models/model-{ano}-{area}-{itemtype}-{method}-b{remove_b}'
    else:
        fn = f'data/models/model-{ano}-{area}-{itemtype}-{method}'
    
    with open(fn,'rb') as pfile:
        model = pickle.load(pfile)
    return model

def estimate_irt(ano,area,itemtype="3PL", method="EM", SE=True,remove_b=None,write_model=True):
    'Estime o modelo. Se já foi estimado, e remove_b é dado, remova itens com abs(b) < remove_b e a < 0'
    df,resp,item_info = load_acertos(ano,area)
    
    if remove_b:
        model = load_model(ano,area,itemtype, method, SE)
        coefs = irt_coefs(model)
        resp.columns = resp.columns.astype(int)
        items_to_remove = coefs.query(f'abs(b) > {remove_b} | a < 0').index
        if len(items_to_remove) > 0:
            resp = resp.drop(columns=items_to_remove)
            print("removing items", coefs.query(f'b > {remove_b}').index)
            model = mirt.mirt(to_rdf(resp),1,itemtype=itemtype,method=method,SE=SE)
            fn = f'data/models/model-{ano}-{area}-{itemtype}-{method}-b{remove_b}'
        else:
            print("No items do remove!")
            return 
    else:
        model = mirt.mirt(to_rdf(resp),1,itemtype=itemtype,method=method,SE=SE)
        fn = f'data/models/model-{ano}-{area}-{itemtype}-{method}'
    if write_model:
        with open(fn, 'wb') as pfile:
            pickle.dump(model,pfile)
        
    return model


for ano in range(2009,2023):
    for area in ['MT','CN','CH']:
        print(f"Ano = {ano}, area = {area}") 
        #_ = estimate_irt(ano,area)
        #_ = estimate_irt(ano,area,remove_b=5)
# Out:
# Ano = 2009, area = MT
# Ano = 2009, area = CN
# Ano = 2009, area = CH
# Ano = 2010, area = MT
# Ano = 2010, area = CN
# Ano = 2010, area = CH
# Ano = 2011, area = MT
# Ano = 2011, area = CN
# Ano = 2011, area = CH
# Ano = 2012, area = MT
# Ano = 2012, area = CN
# Ano = 2012, area = CH
# Ano = 2013, area = MT
# Ano = 2013, area = CN
# Ano = 2013, area = CH
# Ano = 2014, area = MT
# Ano = 2014, area = CN
# Ano = 2014, area = CH
# Ano = 2015, area = MT
# Ano = 2015, area = CN
# Ano = 2015, area = CH
# Ano = 2016, area = MT
# Ano = 2016, area = CN
# Ano = 2016, area = CH
# Ano = 2017, area = MT
# Ano = 2017, area = CN
# Ano = 2017, area = CH
# Ano = 2018, area = MT
# Ano = 2018, area = CN
# Ano = 2018, area = CH
# Ano = 2019, area = MT
# Ano = 2019, area = CN
# Ano = 2019, area = CH
# Ano = 2020, area = MT
# Ano = 2020, area = CN
# Ano = 2020, area = CH
# Ano = 2021, area = MT
# Ano = 2021, area = CN
# Ano = 2021, area = CH
# Ano = 2022, area = MT
# Ano = 2022, area = CN
# Ano = 2022, area = CH

# %%
ano, area = 2009, 'CH'
df,resp,item_info = load_acertos(ano,ar sea,)
len(resp.columns)
# Out:
#   Cell In[49], line 2
#     df,resp,item_info = load_acertos(ano,ar sea,)
#                                             ^
# SyntaxError: invalid syntax

# %%
s = '''
F = 1-43
PRIOR = (1-43,d,norm, 0, 2)
PRIOR = (1-43,a1,lnorm, .2, .2)
START = (1-43,g,0.2)
FIXED = (1-43,g)
'''

# %%
s = '''
F = 1-45
PRIOR = (1-45,d,norm, 0, 10)
PRIOR = (1-45,a1,lnorm, .2, .5)
'''
mirtmodel = mirt.mirt_model(s)
#mirtmodel = mirt.mirt_model("1")
model = mirt.mirt(to_rdf(resp),mirtmodel,itemtype='3PL',method='EM',SE=False)
# Out:
# Iteration: 107, Log-Lik: -245607.190, Max-Change: 0.00076

# %%
irtparams = pd.merge(irt_coefs(model),item_info.set_index('CO_ITEM'),left_index=True,right_index=True)
fig, axs = plt.subplots(1,2,figsize=(16,6))
ax1,ax2 = axs[0],axs[1]
#plt.errorbar(comp_coef['d'],comp_coef['b'],yerr=comp_coef['b_se'],fmt='o')
ax1.scatter(irtparams['NU_PARAM_B'],irtparams['b'])
ax1.plot([-2,6],[-2,6],'r')
ax1.set_ylim(-3,6)
fig.suptitle("Parâmetros do INEP vs Parâmetros reproduzidos")
ax1.set_ylabel("Diculdade nosso modelo");
ax1.set_xlabel("dificuldade INEP");
ax2.scatter(irtparams['NU_PARAM_A'],irtparams['a'])
ax2.plot([0,3.5],[0,3.5],'r')
ax2.set_ylabel("discriminação nosso modelo");
ax2.set_xlabel("discriminação INEP");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 irtparams = pd.merge(irt_coefs(model),item_info.set_index('CO_ITEM'),left_index=True,right_index=True)
#       2 fig, axs = plt.subplots(1,2,figsize=(16,6))
#       3 ax1,ax2 = axs[0],axs[1]
#
# NameError: name 'irt_coefs' is not defined

# %%
to_df(mirt.itemfit(model,fit_stats="infit"))

# %%
def irt_coefs(model):
    coef = rpy2.robjects.r['coef']
    coefs = coef(model,simplify=False,IRTpars=True,printSE=True,verbose=True)
    coefs = to_df(coefs)
    #coefs = pd.DataFrame([np.concatenate([value[0],value[1]]) for key,value in coefs.items()],index=coefs.keys(),columns=['a','b','c','u','a_se','b_se','c_se','u_se'])
    # se o coef acima não fornece erros padrão
    coefs = pd.DataFrame([value[0] for key,value in coefs.items()],index=coefs.keys(),columns=['a','b','c','u'])
    coefs = coefs.drop(index="GroupPars")
    coefs = coefs.set_index(coefs.index.astype('int'))
    coefs = coefs.drop(columns=['u'])
    return coefs

# %%
ano,area = 2011,'CH'
model = load_model(ano,area)
coefs = irt_coefs(model).sort_values('b',ascending=False)
coefs = coefs.join(item_stats(ano,area))

# %%
coefs.query(f'abs(b) > {remove_b} | a < 0')

# %%
# %%R -i model -w 1200 -h 800
# plot(model,type="trace", facet_items=TRUE)

# %%
def calc_thetas(model,method="EAP"):
    thetas = mirt.fscores(model,method="EAP",full_scores=True,full_scores_SE=True)
    return to_df(thetas)[:,0], to_df(thetas)[:,1]

model = load_model(2022,'MT')
thetas,thetasse = calc_thetas(model)
thetasse

# %%
sns.histplot(df,x='thetas1')

# %%
df[['nota_inep','thetas1']].corr()

# %%
ax = sns.scatterplot(df,y='thetas1',x='nota_inep')
ax.set_title("Microdados ENEM\nNossa estimação do modelo TRI")
ax.set_xlabel("Nota INEP")
ax.set_ylabel("Nota nosso modelo")
#sns.scatterplot(df,x='acertos',y='theta3plmap')

# %% [markdown]
# ## INEP Item coefficients

# %%
def irt_coefs_inep(ano,area):
    df, resp, item_info = load_acertos(ano,area)
    resp.columns = resp.columns.astype(int)
    params = item_info[item_info["CO_ITEM"].isin(resp.columns)]
    if len(params) != len(resp.columns):
        print(f"Warning: params has length {len(params)} while resp has {len(resp.columns)} columns")
    params = params[["CO_ITEM","NU_PARAM_A","NU_PARAM_B","NU_PARAM_C"]]
    params = params.set_index("CO_ITEM")
    params.columns = ["a_inep","b_inep","c_inep"]
    return params

# %%
ano,area = 2014,'CN'

model = load_model(ano,area)
try:
    model6 = load_model(ano,area,remove_b=5)
except FileNotFoundError:
    model6 = model

coefs = irt_coefs(model)
coefs = coefs.join(item_stats(ano,area))
coefs6 = irt_coefs(model6)
coefs6 = coefs6.join(item_stats(ano,area))

#comp_coef = pd.merge(coefs,params,left_index=True,right_index=True)

fig, axs = plt.subplots(1,2,figsize=(16,6))
ax1,ax2 = axs[0],axs[1]
#plt.errorbar(comp_coef['d'],comp_coef['b'],yerr=comp_coef['b_se'],fmt='o')
ax1.scatter(coefs['NU_PARAM_B'],coefs['b'])
ax1.scatter(coefs6['NU_PARAM_B'],coefs6['b'])
ax1.plot([-2,6],[-2,6],'r')
ax1.set_ylim(-3,6)
fig.suptitle("Parâmetros do INEP vs Parâmetros reproduzidos")
ax1.set_ylabel("Diculdade nosso modelo");
ax1.set_xlabel("dificuldade INEP");
ax2.scatter(coefs['NU_PARAM_A'],coefs['a'])
ax2.scatter(coefs6['NU_PARAM_A'],coefs6['a'])
ax2.plot([0,3.5],[0,3.5],'r')
ax2.set_ylabel("discriminação nosso modelo");
ax2.set_xlabel("discriminação INEP");

# %%
ano, area = 2009, 'CN'
inep_params = irt_coefs_inep(ano,area)
inep_params['u'] = 1 # a função generate_mirt_object abaixo requer 4 parâmetros para cada item.
# os itens devem corresponder aos das padrões de resposta dos candidatos (o variável resp abaixo).
inep_params = inep_params.sort_index() 
# transformar os parâmetros (essencialmente a da dificuldade) de IRT para "slope / intercept" do mirt.
inep_params = mirt.traditional2mirt(to_rdf(inep_params),"3PL")
mod_inep = mirtcat.generate_mirt_object(to_rdf(inep_params),itemtype = '3PL')
df, resp, item_info = load_acertos(ano,area)
resp.columns = resp.columns.astype(int)
resp = resp.sort_index(axis=1) # se não fizer isso, os itens (colunas nestas padrões de resposta) não correspondem ao modelo mod_inep acima
inepthetas= mirt.fscores(mod_inep,method="EAP",full_scores=True,returnER=False,verbose=True ,response_pattern = to_rdf(resp))
df['ineptheta'] = to_df(inepthetas)[:,0]
df['ineptheta_se'] = to_df(inepthetas)[:,1]

sns.regplot(df,x='ineptheta',y='nota_inep',ci=None,line_kws={"color": "C1"})
#plt.errorbar(df['ineptheta'],df['nota_inep'],xerr=df['ineptheta_se'],errorevery=100,ecolor='mediumblue',alpha=0.4)

# %%
sns.histplot(df,x='nota_inep')

# %%
df.query('nota_inep > 800 & ineptheta < 0' )

# %%
mt2015 = pd.read_csv('data/enem_1_2015.csv')
estranho = mt2015[mt2015['NU_INSCRICAO'] == 150005340871]

# %%
pd.set_option('display.max_rows', 500)
estranho.iloc[0]

# %%
df.sort_values('nota_inep')

# %%
df.sort_values('ineptheta',ascending=False)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(df[x],df[y])
print(slope,intercept)
df[x].std()

# %%
.71*112

# %%
sns.histplot(df['acertos'],discrete=True)

# %%
sns.scatterplot(df,x='inepthetas_eap',y='inepthetasse_eap')

# %%
plt.errorbar(df['nota_inep'],df[x]*slope+intercept,yerr=df[xs]*slope,fmt=".",alpha=0.1)
ax = plt.gca()
ax.set_xlabel("Nota do ENEM do INEP")
ax.set_ylabel("Nota reproduzida + erro padrão")
ax.set_title("Reprodução das notas do ENEM 2019\na partir do microdados");

# %%
sns.scatterplot(x=df['inepthetas_eap'],y=(df['inepthetas_ml']-df['inepthetas_eap']))

# %%
resp0 = resp.iloc[0:10]
resp0

# %%
# %%R -i mod_inep,resp0,resp,model3pl
# respvec <- rep(0,43)
# fscores(mod_inep,method="EAP",full.scores=TRUE,full.scores_SE = TRUE,verbose=TRUE,response.pattern = respvec)

# %%
respvec = [1]*43

# %%
mirt.fscores(mod_inep,method="EAP",full_scores=True, full_scores_SE = True,verbose=True ,response_pattern = to_rdf(respvec))
