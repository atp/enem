# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
pd.read_csv("data/enem_1_2009.csv")
# Out:
#        NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ST_CONCLUSAO  \
# 0      100000000293    2009               14       M              1.0
# 1      100000000455    2009                9       F              1.0
# 2      100000000579    2009                5       M              1.0
# 3      100000000785    2009                7       M              1.0
# 4      100000000867    2009                5       F              2.0
# ...             ...     ...              ...     ...              ...
# 22697  100004145304    2009               11       M              2.0
# 22698  100004146017    2009               12       M              2.0
# 22699  100004146046    2009               12       M              2.0
# 22700  100004147713    2009                3       M              1.0
# 22701  100004147734    2009                6       F              1.0
#
#        TP_ENSINO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  ...  \
# ...

# %%
for i in range(2009, 2022):
    df_nome = f'enem_{i}'

# %%
def read_enem_data():
    dataframes = {}

    for ano in range(2009, 2023):
        file_path = f"data/enem_1_{ano}.csv"
        df = pd.read_csv(file_path)
        dataframes[f"enem_{ano}"] = df
    return dataframes

enem_dataframes = read_enem_data()

column_name = "NU_NOTA_MT"

# Preparação dos dados para o gráfico
years = []
mean_scores = []

for year, df in enem_dataframes.items():
    years.append(year)
    mean_score = df[column_name].mean()  # Calcula a média da coluna "NU_NOTA_MT"
    mean_scores.append(mean_score)

# Criação do gráfico de pontos
plt.figure(figsize=(10, 6))
plt.scatter(years, mean_scores, c='blue', marker='o', alpha=0.7)
plt.xlabel("Ano")
plt.ylabel("Média das Notas de Matemática")
plt.title("Comparação da Média das Notas de Matemática ao longo dos anos")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# Exibe o gráfico
plt.show()
# Out:
# /tmp/ipykernel_69464/2955369587.py:6: DtypeWarning: Columns (87,88,89,90,91,92,93,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
# Criação do boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(data, labels=enem_dataframes.keys())
plt.xlabel("Ano")
plt.ylabel("Notas de Matemática")
plt.title("Distribuição das Notas de Matemática ao longo dos anos")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# Exibe o gráfico
plt.show()
