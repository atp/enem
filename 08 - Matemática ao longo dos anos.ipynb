# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
pd.read_csv("data/enem_1_2009.csv")
# Out:
#        NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ST_CONCLUSAO  \
# 0      100000000293    2009               14       M              1.0
# 1      100000000455    2009                9       F              1.0
# 2      100000000579    2009                5       M              1.0
# 3      100000000785    2009                7       M              1.0
# 4      100000000867    2009                5       F              2.0
# ...             ...     ...              ...     ...              ...
# 22697  100004145304    2009               11       M              2.0
# 22698  100004146017    2009               12       M              2.0
# 22699  100004146046    2009               12       M              2.0
# 22700  100004147713    2009                3       M              1.0
# 22701  100004147734    2009                6       F              1.0
#
#        TP_ENSINO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  ...  \
# ...

# %%
for i in range(2009, 2022):
    df_nome = f'enem_{i}'
# Out:
# enem_2009
# enem_2010
# enem_2011
# enem_2012
# enem_2013
# enem_2014
# enem_2015
# enem_2016
# enem_2017
# enem_2018
# enem_2019
# enem_2020
# enem_2021

# %%
import pandas as pd

def read_enem_data():
    dataframes = {}  

    for i in range(2009, 2023):
        file_path = f"data/enem_1_{i}.csv"  # Caminho do arquivo CSV
        try:
            df = pd.read_csv(file_path)  # Lê o arquivo CSV
            dataframes[f"enem_{i}"] = df  # Adiciona ao dicionário com a chave 'enem_XXXX'
        except FileNotFoundError:
            print(f"Arquivo {file_path} não encontrado.")

    return dataframes

# Chame a função para ler os DataFrames
enem_dataframes = read_enem_data()

# Agora você pode acessar os DataFrames individualmente, por exemplo:
# df_2009 = enem_dataframes["enem_2009"]
# df_2010 = enem_dataframes["enem_2010"]

# Ou iterar sobre eles:
for year, df in enem_dataframes.items():
    print(f"Ano: {year}")
    print(df.head())  # Exibe as primeiras linhas do DataFrame
# Out:
# /tmp/ipykernel_114529/4037876785.py:9: DtypeWarning: Columns (87,88,89,90,91,92,93,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)  # Lê o arquivo CSV
# Ano: enem_2009
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ST_CONCLUSAO  TP_ENSINO  \
# 0  100000000293    2009               14       M              1.0        2.0
# 1  100000000455    2009                9       F              1.0        1.0
# 2  100000000579    2009                5       M              1.0        1.0
# 3  100000000785    2009                7       M              1.0        1.0
# 4  100000000867    2009                5       F              2.0        3.0
#
#    CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  ...  Q284  Q285  \
# 0               NaN              NaN        NaN       NaN  ...     A     B
# 1               NaN              NaN        NaN       NaN  ...     .     .
# ...

# %%
# Out:
# /tmp/ipykernel_114529/140050491.py:10: DtypeWarning: Columns (87,88,89,90,91,92,93,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
