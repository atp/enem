# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
import scipy.stats as stats
import pickle

# %%
import rpy2
import numpy as np

import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri

import rpy2.ipython.html
rpy2.ipython.html.init_printing()

from rpy2.robjects.packages import importr, data


utils = importr('utils')
base = importr('base')
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
def to_rdf(df):
    with (robjects.default_converter + pandas2ri.converter).context():
        rdf = robjects.conversion.get_conversion().py2rpy(df)
    return rdf

def to_df(rdf):
    with (robjects.default_converter + pandas2ri.converter).context():
        df = robjects.conversion.get_conversion().rpy2py(rdf)

    return df
summary = rpy2.robjects.r['summary']
coef = rpy2.robjects.r['coef']
rprint = rpy2.robjects.r['print']
plot = rpy2.robjects.r['plot']

# %%
# %%R
# R.version.string
# Out:
# [1] "R version 4.2.2 Patched (2022-11-10 r83330)"
# In addition: Warning messages:
# 1: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   library ‘/dados1/usr/lib/R/site-library’ contains no packages
# 2: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   library ‘/dados1/usr/lib/R/site-library’ contains no packages
# 3: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   library ‘/dados1/usr/lib/R/site-library’ contains no packages
# 4: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   library ‘/dados1/usr/lib/R/site-library’ contains no packages

# %% [markdown]
# ## Instalar pacotes do R localmente (só para seu usuário)
# Talvez é necessário usar
# ```
# utils.install_packages('mirt')
# utils.install_packages('mirtCAT')
#
# ```
# e o equivalente de outros pacotes. Deu erro instalar devtools desta forma, mas consegui instalar no rstudio.atp.usp.br. agora a linha abaixo funciona:

# %%
utils.install_packages('mirt')
utils.install_packages('mirtCAT')
# Out:
# R[write to console]: Installing package into ‘/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/mirt_1.40.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 534433 bytes (521 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 521 KB
#
#
# * installing *source* package ‘mirt’ ...
# ** package ‘mirt’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/RcppArmadillo/include'   -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c Estep.cpp -o Estep.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/RcppArmadillo/include'   -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c Misc.cpp -o Misc.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/RcppArmadillo/include'   -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c dpars.cpp -o dpars.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/RcppArmadillo/include'   -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c ggum_derivs.cpp -o ggum_derivs.o
# make: *** [ggum_derivs.o] Interrupt
# ERROR: compilation failed for package ‘mirt’
# * removing ‘/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/mirt’
# * restoring previous ‘/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/mirt’
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmp22H2iZ/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Installing package into ‘/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2’
# (as ‘lib’ is unspecified)
# /usr/lib/R/etc/Makeconf:178: recipe for target 'ggum_derivs.o' failed
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/mirtCAT_1.12.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1837427 bytes (1.8 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.8 MB
#
#
# * installing *source* package ‘mirtCAT’ ...
# ** package ‘mirtCAT’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/RcppArmadillo/include'    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c CAT_functions.cpp -o CAT_functions.o
# g++ -std=gnu++14 -I"/usr/share/R/include" -DNDEBUG  -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/Rcpp/include' -I'/dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/RcppArmadillo/include'    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2  -c item_functions.cpp -o item_functions.o
# g++ -std=gnu++14 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o mirtCAT.so CAT_functions.o item_functions.o -llapack -lblas -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR
# installing to /dados1/home/luis/R/x86_64-pc-linux-gnu-library/4.2/00LOCK-mirtCAT/00new/mirtCAT/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (mirtCAT)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmp22H2iZ/downloaded_packages’
# R[write to console]:
# R[write to console]:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7fe8a86c7880> [RTYPES.NILSXP]

# %%
#devtools.install_github('alexandrejaloto/microEnem')

# %%
mirt = importr('mirt')
mirtcat = importr("mirtCAT")
# Out:
# R[write to console]: Error: package or namespace load failed for ‘shiny’ in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]):
#  namespace ‘Rcpp’ 1.0.5 is already loaded, but >= 1.0.7 is required
#
# R[write to console]: Failed with error:
# R[write to console]:
# R[write to console]: ‘package ‘shiny’ could not be loaded’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  library ‘/dados1/usr/lib/R/site-library’ contains no packages
#
# R[write to console]: 2:
# R[write to console]: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  library ‘/dados1/usr/lib/R/site-library’ contains no packages
#
# R[write to console]: Error in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]) :
#   namespace ‘Rcpp’ 1.0.5 is already loaded, but >= 1.0.7 is required
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[24], line 2
#       1 mirt = importr('mirt')
# ----> 2 mirtcat = importr("mirtCAT")
#
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/robjects/packages.py:486, in importr(name, lib_loc, robject_translations, signature_translation, suppress_messages, on_conflict, symbol_r2python, symbol_resolve, data)
#     483 exported_names: typing.Optional[typing.Set[str]]
#     484 if _package_has_namespace(name,
#     485                           _system_file(package=name)):
# --> 486     env = _get_namespace(name)
#     487     version = _get_namespace_version(name)[0]
#     488     exported_names = set(_get_namespace_exports(name))
#
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/rinterface.py:860, in SexpClosure.__call__(self, *args, **kwargs)
#     853     res = rmemory.protect(
#     854         openrlib.rlib.R_tryEval(
#     855             call_r,
#     856             call_context.__sexp__._cdata,
#     857             error_occured)
#     858     )
#     859     if error_occured[0]:
# --> 860         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     861 return res
#
# RRuntimeError: Error in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]) :
#   namespace ‘Rcpp’ 1.0.5 is already loaded, but >= 1.0.7 is required

# %%
ano = 2019
item_info = pd.read_csv(f'../inep/enem/{ano}/DADOS/ITENS_PROVA_{ano}-utf8.csv',sep='\;',engine='python')
item_info.value_counts('TX_MOTIVO_ABAN')

# %%
item_info['IN_ITEM_ABAN'].unique()
# Out:
# array([0, 1])

# %%
item_info.query('IN_ITEM_ABAN == 1')
# Out:
#       CO_POSICAO SG_AREA  CO_ITEM TX_GABARITO  CO_HABILIDADE  IN_ITEM_ABAN  \
# 219           15      LC   118260           E             15             1
# 371           29      LC   118260           E             15             1
# 372           29      LC   118260           E             15             1
# 373           29      LC   118260           E             15             1
# 416           33      LC   118260           E             15             1
# 450           36      LC   118260           E             15             1
# 582           48      CH   118067           C             29             1
# 770           66      CH    76955           B             27             1
# 813           69      CH   118067           C             29             1
# 841           72      CH    76955           B             27             1
# 879           75      CH   118067           C             29             1
# 903           78      CH    76955           B             27             1
# 904           78      CH    76955           B             27             1
# 905           78      CH    76955           B             27             1
# 943           81      CH   118067           C             29             1
# 944           81      CH   118067           C             29             1
# 945           81      CH   118067           C             29             1
# 1037          90      CH    76955           B             27             1
# 1121          98      CN    83609           E             18             1
# 1126          99      CN    42605           B              6             1
# 1190         105      CN    42605           B              6             1
# 1207         107      CN    83609           E             18             1
# 1208         107      CN    83609           E             18             1
# 1209         107      CN    83609           E             18             1
# 1339         120      CN    42605           B              6             1
# 1361         122      CN    83609           E             18             1
# 1429         129      CN    42605           B              6             1
# 1430         129      CN    83609           E             18             1
# 1546         141      MT    23065           C             14             1
# 1547         141      MT    23065           C             14             1
# 1548         141      MT    23065           C             14             1
# 1578         144      MT    28698           C              3             1
# 1585         145      MT    23065           C             14             1
# 1627         149      MT    23065           C             14             1
# 1668         153      MT    23065           C             14             1
# 1738         160      MT    28698           C              3             1
# 1798         166      MT    28698           C              3             1
# 1877         174      MT    28698           C              3             1
#
#                                          TX_MOTIVO_ABAN  NU_PARAM_A  \
# 219   Não permitiu a convergência do algoritmo de es...         NaN
# 371   Não permitiu a convergência do algoritmo de es...         NaN
# 372   Não permitiu a convergência do algoritmo de es...         NaN
# 373   Não permitiu a convergência do algoritmo de es...         NaN
# 416   Não permitiu a convergência do algoritmo de es...         NaN
# 450   Não permitiu a convergência do algoritmo de es...         NaN
# 582   Não permitiu a convergência do algoritmo de es...         NaN
# 770   Não permitiu a convergência do algoritmo de es...         NaN
# 813   Não permitiu a convergência do algoritmo de es...         NaN
# 841   Não permitiu a convergência do algoritmo de es...         NaN
# 879   Não permitiu a convergência do algoritmo de es...         NaN
# 903   Não permitiu a convergência do algoritmo de es...         NaN
# 904   Não permitiu a convergência do algoritmo de es...         NaN
# 905   Não permitiu a convergência do algoritmo de es...         NaN
# 943   Não permitiu a convergência do algoritmo de es...         NaN
# 944   Não permitiu a convergência do algoritmo de es...         NaN
# 945   Não permitiu a convergência do algoritmo de es...         NaN
# 1037  Não permitiu a convergência do algoritmo de es...         NaN
# 1121  Não permitiu a convergência do algoritmo de es...         NaN
# 1126  Não permitiu a convergência do algoritmo de es...         NaN
# 1190  Não permitiu a convergência do algoritmo de es...         NaN
# 1207  Não permitiu a convergência do algoritmo de es...         NaN
# 1208  Não permitiu a convergência do algoritmo de es...         NaN
# 1209  Não permitiu a convergência do algoritmo de es...         NaN
# 1339  Não permitiu a convergência do algoritmo de es...         NaN
# 1361  Não permitiu a convergência do algoritmo de es...         NaN
# 1429  Não permitiu a convergência do algoritmo de es...         NaN
# 1430  Não permitiu a convergência do algoritmo de es...         NaN
# 1546  Não permitiu a convergência do algoritmo de es...         NaN
# 1547  Não permitiu a convergência do algoritmo de es...         NaN
# 1548  Não permitiu a convergência do algoritmo de es...         NaN
# 1578  Não permitiu a convergência do algoritmo de es...         NaN
# 1585  Não permitiu a convergência do algoritmo de es...         NaN
# 1627  Não permitiu a convergência do algoritmo de es...         NaN
# 1668  Não permitiu a convergência do algoritmo de es...         NaN
# 1738  Não permitiu a convergência do algoritmo de es...         NaN
# 1798  Não permitiu a convergência do algoritmo de es...         NaN
# 1877  Não permitiu a convergência do algoritmo de es...         NaN
#
#       NU_PARAM_B  NU_PARAM_C   TX_COR  CO_PROVA  TP_LINGUA  IN_ITEM_ADAPTADO
# 219          NaN         NaN   Branca       514        NaN                 0
# 371          NaN         NaN  Amarela       512        NaN                 0
# 372          NaN         NaN  Laranja       521        NaN                 0
# 373          NaN         NaN    Verde       525        NaN                 1
# 416          NaN         NaN     Azul       511        NaN                 0
# 450          NaN         NaN     Rosa       513        NaN                 0
# 582          NaN         NaN     Azul       507        NaN                 0
# 770          NaN         NaN   Branca       509        NaN                 0
# 813          NaN         NaN   Branca       509        NaN                 0
# 841          NaN         NaN     Rosa       510        NaN                 0
# 879          NaN         NaN     Rosa       510        NaN                 0
# 903          NaN         NaN  Amarela       508        NaN                 0
# 904          NaN         NaN  Laranja       520        NaN                 0
# 905          NaN         NaN    Verde       524        NaN                 1
# 943          NaN         NaN  Amarela       508        NaN                 0
# 944          NaN         NaN  Laranja       520        NaN                 0
# 945          NaN         NaN    Verde       524        NaN                 1
# 1037         NaN         NaN     Azul       507        NaN                 0
# 1121         NaN         NaN  Amarela       504        NaN                 0
# 1126         NaN         NaN     Rosa       546        NaN                 0
# 1190         NaN         NaN    Cinza       544        NaN                 0
# 1207         NaN         NaN    Cinza       505        NaN                 0
# 1208         NaN         NaN  Laranja       519        NaN                 0
# 1209         NaN         NaN    Verde       523        NaN                 1
# 1339         NaN         NaN  Amarela       543        NaN                 0
# 1361         NaN         NaN     Azul       503        NaN                 0
# 1429         NaN         NaN     Azul       545        NaN                 0
# 1430         NaN         NaN     Rosa       506        NaN                 0
# 1546         NaN         NaN    Cinza       518        NaN                 0
# 1547         NaN         NaN  Laranja       522        NaN                 0
# 1548         NaN         NaN    Verde       526        NaN                 1
# 1578         NaN         NaN  Amarela       555        NaN                 0
# 1585         NaN         NaN     Azul       515        NaN                 0
# 1627         NaN         NaN  Amarela       516        NaN                 0
# 1668         NaN         NaN     Rosa       517        NaN                 0
# 1738         NaN         NaN     Rosa       558        NaN                 0
# 1798         NaN         NaN     Azul       557        NaN                 0
# 1877         NaN         NaN    Cinza       556        NaN                 0

# %%
def load_acertos(ano,area,perc=1,remove_abandonados=True):
    'retornamos o df original com os itens + notas_inep e caderno e um com somente itens'
    df = pd.read_csv(f'data/ac_{perc}_{ano}_{area}.csv',index_col='candidato')
    resp = df.iloc[:,:-3] # assume que as últimas 3 colunas são acertos, nota_inep e caderno 
    if remove_abandonados:
        removed_columns = [col for col in resp.columns if col.endswith('-aban')]
        resp = resp.drop(columns=removed_columns)

    item_info = pd.read_csv(f'../inep/enem/{ano}/DADOS/ITENS_PROVA_{ano}-utf8.csv',sep='\;',engine='python')
    item_info.dropna(subset='CO_ITEM',inplace=True)
    item_info['CO_ITEM'] = item_info['CO_ITEM'].astype(int)
    item_info = item_info[item_info['SG_AREA'] == area]
    item_info = item_info.drop_duplicates(subset='CO_ITEM')
    return df,resp,item_info

df,resp,item_info = load_acertos(2009,'CN',remove_abandonados=False)
resp
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 16
#      13     item_info = item_info.drop_duplicates(subset='CO_ITEM')
#      14     return df,resp,item_info
# ---> 16 df,resp,item_info = load_acertos(2009,'CN',remove_abandonados=False)
#      17 resp
#
# Cell In[38], line 3, in load_acertos(ano, area, perc, remove_abandonados)
#       1 def load_acertos(ano,area,perc=1,remove_abandonados=True):
#       2     'retornamos o df original com os itens + notas_inep e caderno e um com somente itens'
# ----> 3     df = pd.read_csv(f'data/ac_{perc}_{ano}_{area}.csv',index_col='candidato')
#       4     resp = df.iloc[:,:-3] # assume que as últimas 3 colunas são acertos, nota_inep e caderno
#       5     if remove_abandonados:
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ac_1_2009_CN.csv'

# %%
def rename_aban(itemname):
    return itemname.strip('-aban')

def item_stats(ano,area):
    acertos, resp, item_info = load_acertos(ano, area,remove_abandonados=False)
    resp.rename(columns=rename_aban,inplace=True)
    istats = mirt.itemstats(to_rdf(resp))
    istats = to_df(istats[1])
    #istats.index = istats.index.astype(int)
    #istats.index = istats.index
    item_info = item_info.drop_duplicates(subset=['CO_ITEM'],keep='first')
    item_info = item_info.set_index('CO_ITEM')
    item_info.index = item_info.index.astype(str)
    istats = pd.merge(istats,item_info,how='left',left_index=True,right_index=True,validate='1:m')
    istats = istats.drop(columns=['CO_HABILIDADE'])
    return istats
istats = item_stats(2019,'CN')
istats.sort_values('total.r',ascending=True)

# %%
def load_model(ano,area,itemtype="3PL", method="EM", SE=True,remove_b=None):
    if remove_b:
        fn = f'data/models/model-{ano}-{area}-{itemtype}-{method}-b{remove_b}'
    else:
        fn = f'data/models/model-{ano}-{area}-{itemtype}-{method}'
    
    with open(fn,'rb') as pfile:
        model = pickle.load(pfile)
    return model

def estimate_irt(ano,area,itemtype="3PL", method="EM", SE=True,remove_b=None,write_model=True):
    'Estime o modelo. Se já foi estimado, e remove_b é dado, remova itens com abs(b) < remove_b e a < 0'
    df,resp,item_info = load_acertos(ano,area)
    
    if remove_b:
        model = load_model(ano,area,itemtype, method, SE)
        coefs = irt_coefs(model)
        resp.columns = resp.columns.astype(int)
        items_to_remove = coefs.query(f'abs(b) > {remove_b} | a < 0').index
        if len(items_to_remove) > 0:
            resp = resp.drop(columns=items_to_remove)
            print("removing items", coefs.query(f'b > {remove_b}').index)
            model = mirt.mirt(to_rdf(resp),1,itemtype=itemtype,method=method,SE=SE)
            fn = f'data/models/model-{ano}-{area}-{itemtype}-{method}-b{remove_b}'
        else:
            print("No items do remove!")
            return 
    else:
        model = mirt.mirt(to_rdf(resp),1,itemtype=itemtype,method=method,SE=SE)
        fn = f'data/models/model-{ano}-{area}-{itemtype}-{method}'
    if write_model:
        with open(fn, 'wb') as pfile:
            pickle.dump(model,pfile)
        
    return model


for ano in range(2009,2023):
    for area in ['MT','CN','CH']:
        print(f"Ano = {ano}, area = {area}") 
        #_ = estimate_irt(ano,area)
        #_ = estimate_irt(ano,area,remove_b=5)

# %%
ano, area = 2009, 'CH'
df,resp,item_info = load_acertos(ano,area)
len(resp.columns)

# %%
s = '''
F = 1-43
PRIOR = (1-43,d,norm, 0, 2)
PRIOR = (1-43,a1,lnorm, .2, .2)
START = (1-43,g,0.2)
FIXED = (1-43,g)
'''

# %%
s = '''
F = 1-45
PRIOR = (1-45,d,norm, 0, 10)
PRIOR = (1-45,a1,lnorm, .2, .5)
'''
mirtmodel = mirt.mirt_model(s)
#mirtmodel = mirt.mirt_model("1")
model = mirt.mirt(to_rdf(resp),mirtmodel,itemtype='3PL',method='EM',SE=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 8
#       6 mirtmodel = mirt.mirt_model(s)
#       7 #mirtmodel = mirt.mirt_model("1")
# ----> 8 model = mirt.mirt(to_rdf(resp),mirtmodel,itemtype='3PL',method='EM',SE=False)
#
# NameError: name 'resp' is not defined

# %%
irtparams = pd.merge(irt_coefs(model),item_info.set_index('CO_ITEM'),left_index=True,right_index=True)
fig, axs = plt.subplots(1,2,figsize=(16,6))
ax1,ax2 = axs[0],axs[1]
#plt.errorbar(comp_coef['d'],comp_coef['b'],yerr=comp_coef['b_se'],fmt='o')
ax1.scatter(irtparams['NU_PARAM_B'],irtparams['b'])
ax1.plot([-2,6],[-2,6],'r')
ax1.set_ylim(-3,6)
fig.suptitle("Parâmetros do INEP vs Parâmetros reproduzidos")
ax1.set_ylabel("Diculdade nosso modelo");
ax1.set_xlabel("dificuldade INEP");
ax2.scatter(irtparams['NU_PARAM_A'],irtparams['a'])
ax2.plot([0,3.5],[0,3.5],'r')
ax2.set_ylabel("discriminação nosso modelo");
ax2.set_xlabel("discriminação INEP");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 irtparams = pd.merge(irt_coefs(model),item_info.set_index('CO_ITEM'),left_index=True,right_index=True)
#       2 fig, axs = plt.subplots(1,2,figsize=(16,6))
#       3 ax1,ax2 = axs[0],axs[1]
#
# NameError: name 'irt_coefs' is not defined

# %%
to_df(mirt.itemfit(model,fit_stats="infit"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 to_df(mirt.itemfit(model,fit_stats="infit"))
#
# NameError: name 'model' is not defined

# %%
def irt_coefs(model):
    coef = rpy2.robjects.r['coef']
    coefs = coef(model,simplify=False,IRTpars=True,printSE=True,verbose=True)
    coefs = to_df(coefs)
    #coefs = pd.DataFrame([np.concatenate([value[0],value[1]]) for key,value in coefs.items()],index=coefs.keys(),columns=['a','b','c','u','a_se','b_se','c_se','u_se'])
    # se o coef acima não fornece erros padrão
    coefs = pd.DataFrame([value[0] for key,value in coefs.items()],index=coefs.keys(),columns=['a','b','c','u'])
    coefs = coefs.drop(index="GroupPars")
    coefs = coefs.set_index(coefs.index.astype('int'))
    coefs = coefs.drop(columns=['u'])
    return coefs

# %%
ano,area = 2011,'CH'
model = load_model(ano,area)
coefs = irt_coefs(model).sort_values('b',ascending=False)
coefs = coefs.join(item_stats(ano,area))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 ano,area = 2011,'CH'
# ----> 2 model = load_model(ano,area)
#       3 coefs = irt_coefs(model).sort_values('b',ascending=False)
#       4 coefs = coefs.join(item_stats(ano,area))
#
# NameError: name 'load_model' is not defined

# %%
coefs.query(f'abs(b) > {remove_b} | a < 0')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 coefs.query(f'abs(b) > {remove_b} | a < 0')
#
# NameError: name 'coefs' is not defined

# %%
# %%R -i model -w 1200 -h 800
# plot(model,type="trace", facet_items=TRUE)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:194, in _find(name, ns)
#     193 try:
# --> 194     obj = ns[obj_path[look_for_i]]
#     195 except KeyError as e:
#
# KeyError: 'model'
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:435, in RMagics._import_name_into_r(self, arg, env, local_ns)
#     434 try:
# --> 435     val = _find(rhs, local_ns)
#     436 except NameError:
#
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:199, in _find(name, ns)
#     198         message += ' Did you forget to remove trailing comma `,` or included spaces?'
# --> 199     raise NameError(message) from e
#     200 look_for_i += 1
#
# NameError: name 'model' is not defined.
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:194, in _find(name, ns)
#     193 try:
# --> 194     obj = ns[obj_path[look_for_i]]
#     195 except KeyError as e:
#
# KeyError: 'model'
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 get_ipython().run_cell_magic('R', '-i model -w 1200 -h 800', 'plot(model,type="trace", facet_items=TRUE)\n')
#
# File /opt/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:916, in RMagics.R(self, line, cell, local_ns)
#     914     with localconverter(converter) as cv:
#     915         for arg in ','.join(args.input).split(','):
# --> 916             self._import_name_into_r(arg, ro.globalenv, local_ns)
#     918 if args.display:
#     919     try:
#
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:442, in RMagics._import_name_into_r(self, arg, env, local_ns)
#     438         warnings.warn(
#     439             f'The shell is None. Unable to look for {rhs}.'
#     440         )
#     441     else:
# --> 442         val = _find(rhs, self.shell.user_ns)
#     443 if val is not None:
#     444     env[lhs] = val
#
# File /opt/miniconda3/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:199, in _find(name, ns)
#     197     if obj_path[look_for_i] == "":
#     198         message += ' Did you forget to remove trailing comma `,` or included spaces?'
# --> 199     raise NameError(message) from e
#     200 look_for_i += 1
#     201 while look_for_i < len(obj_path):
#
# NameError: name 'model' is not defined.

# %%
def calc_thetas(model,method="EAP"):
    thetas = mirt.fscores(model,method="EAP",full_scores=True,full_scores_SE=True)
    return to_df(thetas)[:,0], to_df(thetas)[:,1]

model = load_model(2022,'MT')
thetas,thetasse = calc_thetas(model)
thetasse

# %%
sns.histplot(df,x='thetas1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sns.histplot(df,x='thetas1')
#
# NameError: name 'df' is not defined

# %%
df[['nota_inep','thetas1']].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df[['nota_inep','thetas1']].corr()
#
# NameError: name 'df' is not defined

# %%
ax = sns.scatterplot(df,y='thetas1',x='nota_inep')
ax.set_title("Microdados ENEM\nNossa estimação do modelo TRI")
ax.set_xlabel("Nota INEP")
ax.set_ylabel("Nota nosso modelo")
#sns.scatterplot(df,x='acertos',y='theta3plmap')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 ax = sns.scatterplot(df,y='thetas1',x='nota_inep')
#       2 ax.set_title("Microdados ENEM\nNossa estimação do modelo TRI")
#       3 ax.set_xlabel("Nota INEP")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## INEP Item coefficients

# %%
def irt_coefs_inep(ano,area):
    df, resp, item_info = load_acertos(ano,area)
    resp.columns = resp.columns.astype(int)
    params = item_info[item_info["CO_ITEM"].isin(resp.columns)]
    if len(params) != len(resp.columns):
        print(f"Warning: params has length {len(params)} while resp has {len(resp.columns)} columns")
    params = params[["CO_ITEM","NU_PARAM_A","NU_PARAM_B","NU_PARAM_C"]]
    params = params.set_index("CO_ITEM")
    params.columns = ["a_inep","b_inep","c_inep"]
    return params

# %%
ano,area = 2014,'CN'

model = load_model(ano,area)
try:
    model6 = load_model(ano,area,remove_b=5)
except FileNotFoundError:
    model6 = model

coefs = irt_coefs(model)
coefs = coefs.join(item_stats(ano,area))
coefs6 = irt_coefs(model6)
coefs6 = coefs6.join(item_stats(ano,area))

#comp_coef = pd.merge(coefs,params,left_index=True,right_index=True)

fig, axs = plt.subplots(1,2,figsize=(16,6))
ax1,ax2 = axs[0],axs[1]
#plt.errorbar(comp_coef['d'],comp_coef['b'],yerr=comp_coef['b_se'],fmt='o')
ax1.scatter(coefs['NU_PARAM_B'],coefs['b'])
ax1.scatter(coefs6['NU_PARAM_B'],coefs6['b'])
ax1.plot([-2,6],[-2,6],'r')
ax1.set_ylim(-3,6)
fig.suptitle("Parâmetros do INEP vs Parâmetros reproduzidos")
ax1.set_ylabel("Diculdade nosso modelo");
ax1.set_xlabel("dificuldade INEP");
ax2.scatter(coefs['NU_PARAM_A'],coefs['a'])
ax2.scatter(coefs6['NU_PARAM_A'],coefs6['a'])
ax2.plot([0,3.5],[0,3.5],'r')
ax2.set_ylabel("discriminação nosso modelo");
ax2.set_xlabel("discriminação INEP");

# %%
ano, area = 2009, 'CN'
inep_params = irt_coefs_inep(ano,area)
inep_params['u'] = 1 # a função generate_mirt_object abaixo requer 4 parâmetros para cada item.
# os itens devem corresponder aos das padrões de resposta dos candidatos (o variável resp abaixo).
inep_params = inep_params.sort_index() 
# transformar os parâmetros (essencialmente a da dificuldade) de IRT para "slope / intercept" do mirt.
inep_params = mirt.traditional2mirt(to_rdf(inep_params),"3PL")
mod_inep = mirtcat.generate_mirt_object(to_rdf(inep_params),itemtype = '3PL')
df, resp, item_info = load_acertos(ano,area)
resp.columns = resp.columns.astype(int)
resp = resp.sort_index(axis=1) # se não fizer isso, os itens (colunas nestas padrões de resposta) não correspondem ao modelo mod_inep acima
inepthetas= mirt.fscores(mod_inep,method="EAP",full_scores=True,returnER=False,verbose=True ,response_pattern = to_rdf(resp))
df['ineptheta'] = to_df(inepthetas)[:,0]
df['ineptheta_se'] = to_df(inepthetas)[:,1]

sns.regplot(df,x='ineptheta',y='nota_inep',ci=None,line_kws={"color": "C1"})
#plt.errorbar(df['ineptheta'],df['nota_inep'],xerr=df['ineptheta_se'],errorevery=100,ecolor='mediumblue',alpha=0.4)
# Out:
# <AxesSubplot:xlabel='ineptheta', ylabel='nota_inep'>

# %%
sns.histplot(df,x='nota_inep')
# Out:
# /opt/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <AxesSubplot:xlabel='nota_inep', ylabel='Count'>

# %%
df.query('nota_inep > 800 & ineptheta < 0' )
# Out:
#               38545  61391  41659  32149  81583  33017  82507  26277  28143  \
# candidato
# 150005340871      1      0      0      0      0      0      1      0      0
#
#               49204  ...  40302  62901  41816  39806  14712  acertos  caderno  \
# candidato            ...
# 150005340871      1  ...      1      0      0      0      1       12      243
#
#               nota_inep  ineptheta  ineptheta_se
# candidato
# 150005340871      803.7  -1.059353      0.651251
#
# [1 rows x 50 columns]

# %%
mt2015 = pd.read_csv('data/enem_1_2015.csv')
estranho = mt2015[mt2015['NU_INSCRICAO'] == 150005340871]

# %%
pd.set_option('display.max_rows', 500)
estranho.iloc[0]
# Out:
# NU_INSCRICAO                                                        150005340871
# NU_ANO                                                                      2015
# TP_FAIXA_ETARIA                                                                5
# TP_SEXO                                                                        M
# TP_ESTADO_CIVIL                                                              0.0
# TP_COR_RACA                                                                    1
# TP_NACIONALIDADE                                                               1
# TP_ST_CONCLUSAO                                                                1
# TP_ANO_CONCLUIU                                                                4
# TP_ESCOLA                                                                      1
# TP_ENSINO                                                                    NaN
# IN_TREINEIRO                                                                   0
# CO_MUNICIPIO_ESC                                                             NaN
# NO_MUNICIPIO_ESC                                                             NaN
# CO_UF_ESC                                                                    NaN
# SG_UF_ESC                                                                    NaN
# TP_DEPENDENCIA_ADM_ESC                                                       NaN
# TP_LOCALIZACAO_ESC                                                           NaN
# TP_SIT_FUNC_ESC                                                              NaN
# IN_CERTIFICADO                                                                 0
# NO_ENTIDADE_CERTIFICACAO                                                     NaN
# CO_UF_ENTIDADE_CERTIFICACAO                                                  NaN
# SG_UF_ENTIDADE_CERTIFICACAO                                                  NaN
# CO_MUNICIPIO_PROVA                                                       3162500
# NO_MUNICIPIO_PROVA                                              São João del Rei
# CO_UF_PROVA                                                                   31
# SG_UF_PROVA                                                                   MG
# TP_PRESENCA_CN                                                               1.0
# TP_PRESENCA_CH                                                               1.0
# TP_PRESENCA_LC                                                               1.0
# TP_PRESENCA_MT                                                               1.0
# CO_PROVA_CN                                                                238.0
# CO_PROVA_CH                                                                234.0
# CO_PROVA_LC                                                                239.0
# CO_PROVA_MT                                                                243.0
# NU_NOTA_CN                                                                 614.0
# NU_NOTA_CH                                                                 680.8
# NU_NOTA_LC                                                                 353.3
# NU_NOTA_MT                                                                 803.7
# TX_RESPOSTAS_CN                    DABEEBCDABABDBBDEECABCDEBCACCCABDEBEAADDDCEAD
# TX_RESPOSTAS_CH                    AAACAEAEDBDADEEACEDAEDBACEBEEEBBDCACCCAEDDAAC
# TX_RESPOSTAS_LC                    CEDAABAEDBECDBCEBCACCEBAECCDBBCEBCAABCCEBEEAB
# TX_RESPOSTAS_MT                    DDEDCBCEAADEABEBCCCDBEAAAACECBEDAACBACBDDBDEC
# TP_LINGUA                                                                      0
# TX_GABARITO_CN                     DDCEEEABBBAADDEDBECBCABCAEDCBCAADBCEAAEEDCBCD
# TX_GABARITO_CH                     ADECAEAEDBDADEEACEBCECBACBBCEEBBDEACBCABDDADC
# TX_GABARITO_LC                 CDEAADCDBABDEBECECCDBBEBEABBABDCDADEEDCDAECCAB...
# TX_GABARITO_MT                     DBBBADCADAEAEDCADCBECAAEDACCCEBDECABDBEEDEBCC
# TP_STATUS_REDACAO                                                            1.0
# NU_NOTA_COMP1                                                              100.0
# NU_NOTA_COMP2                                                              140.0
# NU_NOTA_COMP3                                                              140.0
# NU_NOTA_COMP4                                                              120.0
# NU_NOTA_COMP5                                                              100.0
# NU_NOTA_REDACAO                                                            600.0
# Q001                                                                           F
# Q002                                                                           F
# Q003                                                                           E
# Q004                                                                           D
# Q005                                                                         6.0
# Q006                                                                           G
# Q007                                                                           A
# Q008                                                                           C
# Q009                                                                           D
# Q010                                                                           B
# Q011                                                                           A
# Q012                                                                           C
# Q013                                                                           B
# Q014                                                                           B
# Q015                                                                           B
# Q016                                                                           B
# Q017                                                                           A
# Q018                                                                           A
# Q019                                                                           D
# Q020                                                                           B
# Q021                                                                           B
# Q022                                                                           D
# Q023                                                                           B
# Q024                                                                           B
# Q025                                                                           B
# Q026                                                                           B
# Q027                                                                           E
# Q028                                                                           B
# Q029                                                                         5.0
# Q030                                                                         1.0
# Q031                                                                         5.0
# Q032                                                                         4.0
# Q033                                                                         1.0
# Q034                                                                         5.0
# Q035                                                                         5.0
# Q036                                                                         4.0
# Q037                                                                         5.0
# Q038                                                                         3.0
# Q039                                                                         5.0
# Q040                                                                         5.0
# Q041                                                                         NaN
# Q042                                                                           C
# Q043                                                                           A
# Q044                                                                           A
# Q045                                                                           A
# Q046                                                                           A
# Q047                                                                           D
# Q048                                                                           A
# Q049                                                                           A
# Q050                                                                           A
# Name: 32115, dtype: object

# %%
df.sort_values('nota_inep')
# Out:
#               86767  30781  83741  111476  95820  96226  117692  117731  \
# candidato
# 210051356897      0      0      0       0      0      0       0       0
# 210053209235      0      0      0       0      0      0       0       0
# 210053064883      0      0      0       0      0      0       0       0
# 210054121790      0      0      0       0      0      0       0       1
# 210052304718      0      0      0       0      0      0       0       1
# ...             ...    ...    ...     ...    ...    ...     ...     ...
# 210051992938      1      1      1       1      1      1       1       1
# 210051211845      1      0      1       1      1      1       1       1
# 210052099430      1      1      1       1      1      1       1       1
# 210052256432      1      1      1       1      1      1       1       1
# 210053725552      1      1      1       1      1      1       1       1
#
#               67554  37576  ...  82880  117624  30420  27471  88461  acertos  \
# candidato                   ...
# 210051356897      0      0  ...      0       0      0      0      0        1
# 210053209235      0      0  ...      0       0      0      0      0        2
# 210053064883      0      0  ...      0       0      0      0      0        2
# 210054121790      0      0  ...      0       0      0      0      0        3
# 210052304718      0      0  ...      0       0      0      0      0        2
# ...             ...    ...  ...    ...     ...    ...    ...    ...      ...
# 210051992938      1      1  ...      1       1      0      1      1       42
# 210051211845      1      1  ...      1       1      1      1      1       43
# 210052099430      1      1  ...      1       1      1      1      1       42
# 210052256432      1      1  ...      1       1      1      1      1       43
# 210053725552      1      1  ...      1       1      1      1      1       44
#
#               caderno  nota_inep  ineptheta  ineptheta_se
# candidato
# 210051356897      900      354.5  -1.122398      0.660463
# 210053209235      901      354.7  -1.120953      0.660930
# 210053064883      901      355.3  -1.116908      0.662459
# 210054121790      899      355.7  -1.113633      0.663414
# 210052304718      899      355.9  -1.111732      0.661090
# ...               ...        ...        ...           ...
# 210051992938      902      929.0   3.331365      0.348520
# 210051211845      900      934.2   3.380941      0.361232
# 210052099430      901      944.1   3.484358      0.386756
# 210052256432      899      948.5   3.536493      0.400881
# 210053725552      901      953.1   3.596056      0.417132
#
# [17902 rows x 50 columns]

# %%
df.sort_values('ineptheta',ascending=False)
# Out:
#               60083  60084  60085  60086  60087  60088  60089  60090  59286  \
# candidato
# 100002587502      1      1      1      1      1      1      1      1      1
# 100003062333      1      1      1      1      1      1      1      1      1
# 100000330992      1      1      1      1      1      1      1      1      1
# 100003272416      1      1      1      1      1      1      1      1      1
# 100000559281      1      1      1      1      1      1      1      1      1
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 100003909430      1      1      0      0      0      1      0      0      0
# 100001612769      0      0      0      1      0      1      0      0      0
# 100000812717      0      0      0      0      0      0      0      0      0
# 100001903986      1      0      0      1      1      0      0      0      0
# 100000575393      1      0      0      0      1      0      0      0      0
#
#               60091  ...  60148  60149  60150  60151  60152  acertos  caderno  \
# candidato            ...
# 100002587502      1  ...      1      0      1      1      1       42       52
# 100003062333      1  ...      0      1      1      0      1       38       51
# 100000330992      1  ...      0      1      1      1      1       40       52
# 100003272416      1  ...      0      1      1      1      1       40       49
# 100000559281      1  ...      1      1      1      1      1       41       52
# ...             ...  ...    ...    ...    ...    ...    ...      ...      ...
# 100003909430      0  ...      0      0      0      0      0        6       50
# 100001612769      0  ...      0      0      0      0      0        4       52
# 100000812717      0  ...      0      0      0      0      0        3       50
# 100001903986      0  ...      0      0      0      0      0        4       51
# 100000575393      0  ...      0      0      0      0      0        4       50
#
#               nota_inep  ineptheta  ineptheta_se
# candidato
# 100002587502      843.3   1.644379      0.619438
# 100003062333      831.4   0.935031      0.571748
# 100000330992      829.1   0.845564      0.550633
# 100003272416      825.7   0.765648      0.542858
# 100000559281      860.6   0.720816      0.542418
# ...                 ...        ...           ...
# 100003909430      393.3  -5.978028      0.068434
# 100001612769      285.3  -5.978115      0.068281
# 100000812717      321.9  -5.978128      0.068259
# 100001903986      380.7  -5.978149      0.068223
# 100000575393      366.4  -5.978164      0.068198
#
# [22622 rows x 50 columns]

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(df[x],df[y])
print(slope,intercept)
df[x].std()

# %%
.71*112
# Out:
# 79.52

# %%
sns.histplot(df['acertos'],discrete=True)
# Out:
# <AxesSubplot:xlabel='acertos', ylabel='Count'>
