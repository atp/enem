# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Estatisticas basicas de cada competencia

# %%
provas = ["NU_NOTA_CH", "NU_NOTA_CN", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_REDACAO"]
df_selecao[provas].describe()
# Out:
#          NU_NOTA_CH    NU_NOTA_CN    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  31494.000000  31494.000000  31494.000000  31494.000000     31494.000000
# mean     509.503705    477.318410    521.215003    521.616683       580.695371
# std       81.822841     76.437076    109.483550     63.101645       181.475409
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      449.200000    417.300000    433.100000    484.500000       480.000000
# 50%      512.100000    468.900000    497.500000    526.850000       580.000000
# 75%      568.800000    531.600000    596.500000    566.000000       680.000000
# max      793.000000    808.700000    985.000000    759.200000      1000.000000

# %%
#Estatiticas basicas de ciencias humanas
df_selecao["NU_NOTA_CH"].describe()
# Out:
# count    31494.000000
# mean       509.503705
# std         81.822841
# min          0.000000
# 25%        449.200000
# 50%        512.100000
# 75%        568.800000
# max        793.000000
# Name: NU_NOTA_CH, dtype: float64

# %%
#Estatistica de ciencias da natureza
df_selecao["NU_NOTA_CN"].describe()
# Out:
# count    31494.000000
# mean       477.318410
# std         76.437076
# min          0.000000
# 25%        417.300000
# 50%        468.900000
# 75%        531.600000
# max        808.700000
# Name: NU_NOTA_CN, dtype: float64

# %%
#Estatisticas basicas de matematica
df_selecao["NU_NOTA_MT"].describe()
# Out:
# count    31494.000000
# mean       521.215003
# std        109.483550
# min          0.000000
# 25%        433.100000
# 50%        497.500000
# 75%        596.500000
# max        985.000000
# Name: NU_NOTA_MT, dtype: float64

# %%
#Estatisticas basicas de linguagens
df_selecao["NU_NOTA_LC"].describe()
# Out:
# count    31494.000000
# mean       521.616683
# std         63.101645
# min          0.000000
# 25%        484.500000
# 50%        526.850000
# 75%        566.000000
# max        759.200000
# Name: NU_NOTA_LC, dtype: float64

# %%
#Estatististicas basicas redacao
df_selecao["NU_NOTA_REDACAO"].describe()
# Out:
# count    31494.000000
# mean       580.695371
# std        181.475409
# min          0.000000
# 25%        480.000000
# 50%        580.000000
# 75%        680.000000
# max       1000.000000
# Name: NU_NOTA_REDACAO, dtype: float64

# %% [markdown]
# ## Visualizacao de em graficos de cada competencia

# %% [markdown]
# ### Boxplot das competencias

# %%
dff[provas].plot.box(grid = True, figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
df.query("TX_GABARITO_MT == TX_RESPOSTAS_MT")
# Out:
# Empty DataFrame
# ...

# %%
df["TX_GABARITO_LC"]
# Out:
# 0        EBBADCABDABACBCEBDEEAAADDBECDECDDBADBCDAAECBCC...
# 1        BBEDABDACACBABAECBBCCADCEBDBBCDDEEAAADDBECDECA...
# 2        BBEDABDACACBABAECBBCCADCEBDBBCDDEEAAADDBECDECA...
# 3        BBEDABDACACBABAECBBCCADCEBDBBCDDEEAAADDBECDECA...
# 4        ADBBEDCABAABBCBCDAAECDDDBAAAECADECDCEBDEEAECBD...
#                                ...
# 31489    BDABEABCADBCBAADDBECDAAECDAECBECBCCDEEAAADDBBC...
# 31490    BBEDABDACACBABAECBBCCADCEBDBBCDDEEAAADDBECDECA...
# 31491    BBEDABDACACBABAECBBCCADCEBDBBCDDEEAAADDBECDECA...
# 31492    BDABEABCADBCBAADDBECDAAECDAECBECBCCDEEAAADDBBC...
# 31493    BBEDABDACACBABAECBBCCADCEBDBBCDDEEAAADDBECDECA...
# Name: TX_GABARITO_LC, Length: 31494, dtype: object

# %% [markdown]
# ### Histograma das competencias

# %%
# Histograma ciencias humanas
dff["NU_NOTA_CH"].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
# Histograma ciencias da natureza
dff["NU_NOTA_CN"].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
# Histograma matematica
dff["NU_NOTA_MT"].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
# Histograma codigos
dff["NU_NOTA_LC"].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
# Histogramas redacao
dff["NU_NOTA_REDACAO"].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Perfil social dos estudantes

# %% [markdown]
# ### Idade

# %%
#Mostra quantos alunos tem de cada idade
df_selecao['NU_IDADE'].value_counts()
# Out:
# 18    6700
# 17    5739
# 19    4255
# 20    2884
# 21    1858
# 22    1460
# 23    1161
# 24     946
# 25     717
# 26     622
# 27     494
# 28     403
# 29     355
# 30     310
# 31     292
# 33     253
# 16     252
# 32     246
# 34     231
# 36     205
# 35     193
# 37     179
# 38     177
# 39     167
# 40     142
# 42     140
# 41     126
# 43     118
# 44      93
# 46      77
# 49      72
# 45      72
# 48      65
# 47      65
# 50      59
# 52      46
# 53      36
# 51      36
# 55      36
# 54      34
# 56      33
# 57      24
# 58      19
# 59      16
# 60      12
# 62      11
# 15      11
# 61      10
# 63      10
# 64       7
# 71       4
# 66       4
# 68       3
# 67       3
# 73       3
# 69       2
# 65       2
# 70       2
# 80       1
# 14       1
# Name: NU_IDADE, dtype: int64

# %%
# Estatisca basica de idade
idade = ["NU_IDADE"]
df_selecao[idade].describe()
# Out:
#            NU_IDADE
# count  31494.000000
# mean      21.977932
# std        7.246738
# min       14.000000
# 25%       18.000000
# 50%       19.000000
# 75%       23.000000
# max       80.000000

# %%
# Grafico de pizza das idades

s1 = df_selecao.groupby('NU_IDADE').size()

plt.pie(s1, labels=s1.index)

plt.title('Gráfico de pizza das faixas etarias')

plt.show()
# QUero juntar todas as idades acima de 30 anos para ajudar na vizualizacao

# %%
for i in range(2, 10, 2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
[i for i in range(2, 10, 2)]
# Out:
# [2, 4, 6, 8]

# %%
# Histograma das idades, melhor para ver do que o grafico de pizza enquanto nao consigo agrupar as idades acima de 30 anos
df_selecao["NU_IDADE"].hist(bins = range(16,70, 1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Raca dos participantes

# %%
# Saber quantos de cada fizeram o enem
raca = ["TP_COR_RACA"]
df_selecao[raca].value_counts()
# Out:
# TP_COR_RACA
# 3              14824
# 1              11098
# 2               4041
# 4                718
# 0                631
# 5                182
# dtype: int64

# %%
# Fazendo um fgrafico de pizza para as racas dos participantes

s2 = df_selecao.groupby('TP_COR_RACA').size()

plt.pie(s2, labels=s2.index)

plt.title('Gráfico de pizza do perfil racial')

plt.show()

# %%
# Mudar manualmente o nome dos rotulos para o nome das racas e nao os numeros
quantidade = [596, 11066, 4213,  14796, 791, 196,0]
rotulos = ["Não declarado", "Branca", "Preta", "Parda", "Amarela", "Indígena", "Não dispõe da informação"]


plt.pie(quantidade, labels=rotulos)

plt.show()

# %% [markdown]
# ### Pessoas que acertaram tudo em cada compencia

# %%
df["TX_RESPOSTAS_CN"]
# Out:
# 0        DEDDDECEDCECDEBBBCBCBBBEBDEBCBDEDBADCAEBDDCBB
# 1        CECEEEBEDDBEECDDBBBCBBACBDEEDBABCBAEECBEACBBA
# 2        AEEECCDEDBBCEDDADCDEEDABBBCDCDDBECBCEADEBAABB
# 3        EDCCEBDEEAACBCDCCAACDCAEEDCBDEBBAEAABBECBADDC
# 4        BEDADBCBBBBAAAADDDDEEBEAABBCDADEDACCCDCBADEEA
#                              ...
# 31489    EACBEDCCEDBDEBDABBAEEBEDACEADEEDDECCECDEDACCD
# 31490    DBBDBEEDACDEADCCDEDBCDCDECECEBBBDCEADADEDACAE
# 31491    ADCABDBBDDDDEAEAAAABAAA.AEABAAAADEBAADEEECDDD
# 31492    DEADACDBABDCDEDBDCADBEDAEDECCBBACADAECEBADBBD
# 31493    EBDBDDDCABCCEDABACCDEABBDAABADBBCCABCEDECDDCE
# Name: TX_RESPOSTAS_CN, Length: 31494, dtype: object

# %%
raca = ["TP_COR_RACA"]
df_selecao[raca].describe()
# Out:
#         TP_COR_RACA
# count  31494.000000
# mean       2.141170
# std        1.013176
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        5.000000

# %%
dff.groupby("TP_COR_RACA")["NU_NOTA_MT"].std()
# Out:
# TP_COR_RACA
# 0    124.224439
# 1    118.844581
# 2     92.950406
# 3    100.657366
# 4    110.563489
# 5     75.359497
# Name: NU_NOTA_MT, dtype: float64

# %%
ax = dff.boxplot(column = "NU_NOTA_MT", by = "TP_COR_RACA")
ax.set_ylim(300,800)
# Out:
# (300.0, 800.0)

# %%
notas_selecao.boxplot(column = "NU_NOTA_LC", by = "TP_COR_RACA")
# Out:
# <AxesSubplot:title={'center':'NU_NOTA_LC'}, xlabel='TP_COR_RACA'>

# %%
dff.boxplot(column = "NU_NOTA_CH", by = "TP_COR_RACA")
# Out:
# <AxesSubplot:title={'center':'NU_NOTA_CH'}, xlabel='TP_COR_RACA'>

# %%
dff.boxplot(column = "NU_NOTA_CN", by = "TP_COR_RACA")
# Out:
# <AxesSubplot:title={'center':'NU_NOTA_CN'}, xlabel='TP_COR_RACA'>

# %%
dff.boxplot(column = "NU_NOTA_REDACAO", by = "TP_COR_RACA")
# Out:
# <AxesSubplot:title={'center':'NU_NOTA_REDACAO'}, xlabel='TP_COR_RACA'>

# %%
#Teste
